# %% [markdown]
# # Project  - Human Activity Recognition using Smartphones

# %% [markdown]
# ### The aim of this project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying using data recorded by multiple smartphone sensors.

# %% [markdown]
# ##### DATASET information
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.

# %% [markdown]
# ### First we will try to understand the training and testing data using different Exploratory Data Analysis techniques and visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Loading the datasets

# %%
train = pd.read_csv(r'C:\Users\KIIT\Documents\LGM-Soc contributions\Human Activity Recognition using Smartphones\Dataset/train.csv')
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %%
test = pd.read_csv(r'C:\Users\KIIT\Documents\LGM-Soc contributions\Human Activity Recognition using Smartphones\Dataset/test.csv')
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
test.shape
# Out:
# (2947, 563)

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# ######  Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# #### Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# #### Checking for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='Activity', data = train)
plt.show()

# %% [markdown]
# Inference - Dataset has same number of reading from all the subjects means there are not sygnificant difference in reading then we should not worry about it

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.Activity)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Inference - There is no significant imbalance in the data

# %% [markdown]
# #### Analysis of the activity feature to understand how many types of activites have been performed

# %%
print(train.Activity.unique())
print("----------------------------------------")
print(train.Activity.value_counts())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']
# ----------------------------------------
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
sns.set(rc={'figure.figsize':(13,6)})
fig = sns.countplot(x = "Activity" , data = train)
plt.xlabel("Activity")
plt.ylabel("Count")
plt.title("Activity Count")
plt.grid(True)
plt.show(fig)

# %%
pd.crosstab(train.subject, train.Activity, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col5{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow5_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col3{
#             background-color:  #fffe00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col3{
#             background-color:  #fff500;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col6{
#             background-color:  #fffc00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow0_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow2_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow3_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow4_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow6_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow7_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow19_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col2{
#             background-color:  #fffd00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow1_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow8_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow13_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow14_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col6,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col3{
#             background-color:  #fffb00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow9_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow10_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col4,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col1{
#             background-color:  #fffa00;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow11_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col3,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow15_col5,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow17_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow18_col2,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col5{
#             background-color:  #fff900;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col0,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow16_col1,#T_f71f3ae2_d745_11eb_9518_c465162ded5crow20_col4{
#             background-color:  #fff800;
#             color:  #000000;
#         }#T_f71f3ae2_d745_11eb_9518_c465162ded5crow12_col1,#T_f71f3ae2_d745_11eb_9518_c46516

# %% [markdown]
# ###  Cleaning the feature names for an easy understanding

# %% [markdown]
# Removing the commas and brackets from the feature names

# %%
columns = train.columns

columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ## Saving the new dataframes with cleaned feature names in csv files

# %%
train.to_csv(r'C:\Users\KIIT\Documents\LGM-Soc contributions\Human Activity Recognition using Smartphones\Dataset/cleaned_train.csv', index=False)

# %%
test.to_csv(r'C:\Users\KIIT\Documents\LGM-Soc contributions\Human Activity Recognition using Smartphones\Dataset/cleaned_test.csv', index=False)

# %% [markdown]
# ##  Exploratory Data Analysis

# %% [markdown]
# ###  Visualization of the Stationary and Moving activities

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
.add_legend()
plt.annotate("Stationary Activities", xy=(-0.87,12), xytext=(-0.8, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Maximizing the Static and Dynamic activities plots

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]



plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.title("Static Activities(closer view)")
sns.distplot(train[train["Activity"]=="SITTING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["Activity"]=="STANDING"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["Activity"]=="LAYING"]['tBodyAccMagmean'],hist = False, label = 'Laying')
plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)
plt.title("Dynamic Activities(closer view)")
sns.distplot(train[train["Activity"]=="WALKING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["Activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["Activity"]=="WALKING_UPSTAIRS"]['tBodyAccMagmean'],hist = False, label = 'Laying')
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Dynamic Activities(closer view)'}, xlabel='tBodyAccMagmean', ylabel='Density'>

# %% [markdown]
# ### Vusualization of the magnitude of acceleration data captured by the accelerometer sensor of the smartphone

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ###### Inference
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### Visualizing the position of GravityAccelerationComponants data captured by the gyroscopic sensor of the smartphone

# %%
sns.boxplot(x='Activity', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# ###### Inference
# - If angleX,gravityMean > 0 then Activity is Laying.
# - We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='Activity', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ### Visualizations for feature distribution in space.

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ##### Feature Columns : 0 - 10

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in train.columns[0:10]:
    index = index + 1
    fig = sns.kdeplot(train[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.legend(train.columns[0:10])
plt.grid(True)
plt.show(fig)

# %% [markdown]
# ##### Feature Columns : 10 - 20

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in train.columns[10:20]:
    index = index + 1
    ax1 = sns.kdeplot(train[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.legend(train.columns[10:20])
plt.grid(True)
plt.show(fig)

# %% [markdown]
# ##### Feature Columns : 20 - 30

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in train.columns[20:30]:
    index = index + 1
    ax1 = sns.kdeplot(train[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.legend(train.columns[20:30])
plt.grid(True)
plt.show(fig)

# %% [markdown]
# ##### Feature Columns : 30 - 40

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in train.columns[30:40]:
    index = index + 1
    ax1 = sns.kdeplot(train[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.legend(train.columns[30:40])
plt.grid(True)
plt.show(fig)

# %% [markdown]
# ##### Feature Columns : 40 - 50

# %%
sns.set(rc={'figure.figsize':(15,7)})
colours = ["maroon","coral","darkorchid","goldenrod","purple","darkgreen","darkviolet","saddlebrown","aqua","olive"]
index = -1
for i in train.columns[40:50]:
    index = index + 1
    ax1 = sns.kdeplot(train[i] , shade=True, color=colours[index])
plt.xlabel("Features")
plt.ylabel("Value")
plt.title("Feature Distribution")
plt.legend(train.columns[40:50])
plt.grid(True)
plt.show(fig)

# %% [markdown]
# ### Visualizations with stripplot

# %%
sns.set(rc={'figure.figsize':(15,10)})
plt.subplot(221)
fig1 = sns.stripplot(x='Activity', y= train.loc[train['Activity']=="STANDING"].iloc[:,10], data= train.loc[train['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig1)
plt.subplot(224)
fig2 = sns.stripplot(x='Activity', y=train.loc[train['Activity']=="STANDING"].iloc[:,11], data= train.loc[train['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)
plt.subplot(223)
fig2 = sns.stripplot(x='Activity', y= train.loc[train['Activity']=="STANDING"].iloc[:,12], data= train.loc[train['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)
plt.subplot(222)
fig2 = sns.stripplot(x='Activity', y= train.loc[train['Activity']=="STANDING"].iloc[:,13], data= train.loc[train['Activity']=="STANDING"], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig2)

# %%
sns.set(rc={'figure.figsize':(15,5)})
fig1 = sns.stripplot(x='Activity', y= train.loc[train['subject']==15].iloc[:,7], data= train.loc[train['subject']==15], jitter=True)
plt.title("Feature Distribution")
plt.grid(True)
plt.show(fig1)

# %% [markdown]
# ###  Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Performing t-sne with different perplexity values and their repective plots..

# %%
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
       
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20])
# Out:
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.008s...
# [t-SNE] Computed neighbors for 7352 samples in 1.650s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.085s
# [t-SNE] Iteration 50: error = 113.9613724, gradient norm = 0.0234371 (50 iterations in 3.157s)
# [t-SNE] Iteration 100: error = 97.6178513, gradient norm = 0.0147320 (50 iterations in 2.271s)
# [t-SNE] Iteration 150: error = 93.1782150, gradient norm = 0.0084309 (50 iterations in 2.116s)
# [t-SNE] Iteration 200: error = 91.1750031, gradient norm = 0.0061820 (50 iterations in 2.149s)
# [t-SNE] Iteration 250: error = 89.9697647, gradient norm = 0.0051342 (50 iterations in 2.121s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.969765
# [t-SNE] Iteration 300: error = 3.5734782, gradient norm = 0.0014648 (50 iterations in 2.046s)
# [t-SNE] Iteration 350: error = 2.8140202, gradient norm = 0.0007578 (50 iterations in 2.046s)
# [t-SNE] Iteration 400: error = 2.4329662, gradient norm = 0.0005234 (50 iterations in 2.142s)
# [t-SNE] Iteration 450: error = 2.2154415, gradient norm = 0.0004000 (50 iterations in 2.119s)
# [t-SNE] Iteration 500: error = 2.0704191, gradient norm = 0.0003343 (50 iterations in 2.079s)
# [t-SNE] Iteration 550: error = 1.9650943, gradient norm = 0.0002871 (50 iterations in 2.096s)
# [t-SNE] Iteration 600: error = 1.8841248, gradient norm = 0.0002467 (50 iterations in 2.147s)
# [t-SNE] Iteration 650: error = 1.8187029, gradient norm = 0.0002215 (50 iterations in 2.118s)
# [t-SNE] Iteration 700: error = 1.7651615, gradient norm = 0.0001968 (50 iterations in 2.112s)
# [t-SNE] Iteration 750: error = 1.7197737, gradient norm = 0.0001778 (50 iterations in 2.602s)
# [t-SNE] Iteration 800: error = 1.6809556, gradient norm = 0.0001654 (50 iterations in 2.689s)
# [t-SNE] Iteration 850: error = 1.6471567, gradient norm = 0.0001549 (50 iterations in 2.156s)
# [t-SNE] Iteration 900: error = 1.6172957, gradient norm = 0.0001440 (50 iterations in 2.164s)
# [t-SNE] Iteration 950: error = 1.5908685, gradient norm = 0.0001347 (50 iterations in 2.119s)
# [t-SNE] Iteration 1000: error = 1.5671399, gradient norm = 0.0001266 (50 iterations in 2.146s)
# [t-SNE] KL divergence after 1000 iterations: 1.567140
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# [t-SNE] Computed neighbors for 7352 samples in 1.755s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.090s
# [t-SNE] Iteration 50: error = 105.8312225, gradient norm = 0.0187375 (50 iterations in 3.078s)
# [t-SNE] Iteration 100: error = 90.5270081, gradient norm = 0.0100166 (50 iterations in 2.526s)
# [t-SNE] Iteration 150: error = 87.3917847, gradient norm = 0.0056519 (50 iterations in 2.644s)
# [t-SNE] Iteration 200: error = 86.1349945, gradient norm = 0.0047395 (50 iterations in 2.491s)
# [t-SNE] Iteration 250: error = 85.4296112, gradient norm = 0.0030388 (50 iterations in 2.406s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.429611
# [t-SNE] Iteration 300: error = 3.1393785, gradient norm = 0.0013967 (50 iterations in 2.350s)
# [t-SNE] Iteration 350: error = 2.4953115, gradient norm = 0.0006491 (50 iterations in 2.449s)
# [t-SNE] Iteration 400: error = 2.1747868, gradient norm = 0.0004292 (50 iterations in 2.381s)
# [t-SNE] Iteration 450: error = 1.9899178, gradient norm = 0.0003152 (50 iterations in 2.280s)
# [t-SNE] Iteration 500: error = 1.8715888, gradient norm = 0.0002561 (50 iterations in 2.338s)
# [t-SNE] Iteration 550: error = 1.7879574, gradient norm = 0.0002104 (50 iterations in 2.260s)
# [t-SNE] Iteration 600: error = 1.7251627, gradient norm = 0.0001810 (50 iterations in 2.246s)
# [t-SNE] Iteration 650: error = 1.6758916, gradient norm = 0.0001619 (50 iterations in 2.320s)
# [t-SNE] Iteration 700: error = 1.6361148, gradient norm = 0.0001459 (50 iterations in 2.393s)
# [t-SNE] Iteration 750: error = 1.6032352, gradient norm = 0.0001300 (50 iterations in 2.694s)
# [t-SNE] Iteration 800: error = 1.5756973, gradient norm = 0.0001193 (50 iterations in 2.836s)
# [t-SNE] Iteration 850: error = 1.5520961, gradient norm = 0.0001109 (50 iterations in 2.808s)
# [t-SNE] Iteration 900: error = 1.5321124, gradient norm = 0.0001030 (50 iterations in 2.827s)
# [t-SNE] Iteration 950: error = 1.5146563, gradient norm = 0.0000960 (50 iterations in 2.680s)
# [t-SNE] Iteration 1000: error = 1.4992629, gradient norm = 0.0000899 (50 iterations in 2.732s)
# [t-SNE] KL divergence after 1000 iterations: 1.499263
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.008s...
# [t-SNE] Computed neighbors for 7352 samples in 1.810s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.233s
# [t-SNE] Iteration 50: error = 97.5338211, gradient norm = 0.0197358 (50 iterations in 4.622s)
# [t-SNE] Iteration 100: error = 83.8075867, gradient norm = 0.0068033 (50 iterations in 3.352s)
# [t-SNE] Iteration 150: error = 81.8528671, gradient norm = 0.0034690 (50 iterations in 2.799s)
# [t-SNE] Iteration 200: error = 81.1383896, gradient norm = 0.0032158 (50 iterations in 3.022s)
# [t-SNE] Iteration 250: error = 80.7569504, gradient norm = 0.0017721 (50 iterations in 2.846s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.756950
# [t-SNE] Iteration 300: error = 2.6965313, gradient norm = 0.0013079 (50 iterations in 2.791s)
# [t-SNE] Iteration 350: error = 2.1629558, gradient norm = 0.0005740 (50 iterations in 2.947s)
# [t-SNE] Iteration 400: error = 1.9139723, gradient norm = 0.0003457 (50 iterations in 2.750s)
# [t-SNE] Iteration 450: error = 1.7678739, gradient norm = 0.0002467 (50 iterations in 2.669s)
# [t-SNE] Iteration 500: error = 1.6741866, gradient norm = 0.0001924 (50 iterations in 2.687s)
# [t-SNE] Iteration 550: error = 1.6099724, gradient norm = 0.0001575 (50 iterations in 2.619s)
# [t-SNE] Iteration 600: error = 1.5634974, gradient norm = 0.0001341 (50 iterations in 2.716s)
# [t-SNE] Iteration 650: error = 1.5283147, gradient norm = 0.0001168 (50 iterations in 2.664s)
# [t-SNE] Iteration 700: error = 1.5011131, gradient norm = 0.0001066 (50 iterations in 2.611s)
# [t-SNE] Iteration 750: error = 1.4796187, gradient norm = 0.0000969 (50 iterations in 2.650s)
# [t-SNE] Iteration 800: error = 1.4619993, gradient norm = 0.0000911 (50 iterations in 2.798s)
# [t-SNE] Iteration 850: error = 1.4478009, gradient norm = 0.0000849 (50 iterations in 3.095s)
# [t-SNE] Iteration 900: error = 1.4359829, gradient norm = 0.0000820 (50 iterations in 2.908s)
# [t-SNE] Iteration 950: error = 1.4267232, gradient norm = 0.0000767 (50 iterations in 2.910s)
# [t-SNE] Iteration 1000: error = 1.4188800, gradient norm = 0.0000730 (50 iterations in 2.861s)
# [t-SNE] KL divergence after 1000 iterations: 1.418880
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# ##### Inference
#
# - As we can see all the features except standing and sitting can be seperated very easily
#
# - Models will probably be confused between standing and sitting

# %% [markdown]
# ### Now that we have cleaned and visualized the data we can use this data train our classifier model and ANN model to make predictions
