# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 !/.kaggle/kaggle.json
# Out:
# chmod: cannot access '!/.kaggle/kaggle.json': No such file or directory

# %%
import os
import kaggle

os.environ['KAGGLE_CONFIG_DIR'] = '/root/.kaggle/'
kaggle.api.authenticate()

kaggle.api.dataset_download_files('linkanjarad/body-parts-dataset', unzip=True)

# %% [markdown]
# # Body Parts Recognition Model
#
# - Dataset from Kaggle [Link](https://www.kaggle.com/datasets/linkanjarad/body-parts-dataset).

# %%
import os
import random
import cv2
import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let's See the Dataset and Plot it

# %% [markdown]
# ### Show the images of `BELLY`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Belly'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `EAR`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Ear'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `ELBOW`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Elbow'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `EYE`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Eye'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `FOOT`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Foot'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `HAND`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Hand'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `KNEE`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Knee'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `NECK`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Neck'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `NOSE`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Nose'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ### Show the images of `SHOULDERS`

# %%
# Directory containing your image dataset
image_dir = '/content/Body Parts Dataset/Shoulders'

# List all image files in the directory
image_files = [file for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Number of images to showcase
num = 5

# Plot the images
fig, axes = plt.subplots(1, num, figsize=(15, 3))

for i in range(num):
    # Read and display each image using OpenCV
    image_path = os.path.join(image_dir, image_files[i])
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(image_files[i])

plt.show()

# %% [markdown]
# ## A function which build 2 seprate sets i.e., Training and testing sets to train the model

# %%
def buildDataset(name):
    names = []
    sourcePath = f'/content/Body Parts Dataset/{name}'

    # Check if the source directory exists
    if not os.path.exists(sourcePath):
        print(f"Source directory '{sourcePath}' does not exist.")
        return

    # Create the destination directories if they don't exist
    trainPath = f'/content/dataset/train/{name}'
    testPath = f'/content/dataset/test/{name}'

    os.makedirs(trainPath, exist_ok=True)
    os.makedirs(testPath, exist_ok=True)

    for filename in os.listdir(sourcePath):
        names.append(filename)

    # Shuffling of the whole dataset
    random.shuffle(names)

    # Split dataset into train and test set
    train = names[0: int(0.8*len(names))]
    test = names[int(0.8*len(names)): len(names)+1]

    # Store the prepared data into separate dataset folder
    # Storing the training dataset
    for i in train:
        filePath = os.path.join(sourcePath, i)
        img = cv2.imread(filePath)
        cv2.imwrite(os.path.join(trainPath, i), img)

    # Storing the testing dataset
    for i in test:
        filePath = os.path.join(sourcePath, i)
        img = cv2.imread(filePath)
        cv2.imwrite(os.path.join(testPath, i), img)

# %%
dataset = ['Belly', 'Ear', 'Elbow', 'Eye', 'Foot', 'Hand', 'Knee', 'Neck', 'Nose', 'Shoulders']

# Building the train and test dataset for model training.
for name in dataset:
  buildDataset(name)

# %% [markdown]
# ## Refactoring the images and scale them to fit for the model.

# %%
# path of the train and test dataset
trainPath = '/content/dataset/train'
testPath = '/content/dataset/test'

# %%
generator = ImageDataGenerator(rescale = 1.0/255.0)

# Normalise the train dataset
trainImageGenerator = generator.flow_from_directory(trainPath,
                                                   target_size=(150, 150),
                                                   batch_size=32,
                                                   class_mode='categorical')

# Normalise the test dataset
testImageGenerator = generator.flow_from_directory(testPath,
                                                   target_size=(150, 150),
                                                   batch_size=32,
                                                   class_mode='categorical')
# Out:
# Found 2010 images belonging to 10 classes.
# Found 764 images belonging to 10 classes.

# %%
classMap = dict([v, k] for k, v in trainImageGenerator.class_indices.items())
print(classMap)
# Out:
# {0: 'Belly', 1: 'Ear', 2: 'Elbow', 3: 'Eye', 4: 'Foot', 5: 'Hand', 6: 'Knee', 7: 'Neck', 8: 'Nose', 9: 'Shoulders'}

# %% [markdown]
# ## Building the model.
# - Start with Convolution layers.
# - Then Maxpooling layers.
# - After a neural network, Creating a Fully-connected layers.
# - Now, flatten all the layers in a single dimenstion to create a Fully-connected layers.
# - There is a Dropout layer in between the Fully-connected layers.

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', input_shape=[150, 150, 3]))
model.add(MaxPooling2D(2,))
model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPooling2D(2))

# Flatten the feature map
model.add(Flatten())

# Add the fully connected layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# print(the model summary)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 128)               11214976
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 10)                1290
#
# ...
# Total params: 11252170 (42.92 MB)
# Trainable params: 11252170 (42.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model on **Adam** Optimizer with **Categorical Crossentropy** loss function.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics='accuracy')

# %% [markdown]
# ### Model training begins

# %%
model.fit(trainImageGenerator, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 92s 1s/step - loss: 2.4236 - accuracy: 0.1318
# Epoch 2/20
# 63/63 [==============================] - 85s 1s/step - loss: 2.1202 - accuracy: 0.2269
# Epoch 3/20
# 63/63 [==============================] - 81s 1s/step - loss: 1.7535 - accuracy: 0.4020
# Epoch 4/20
# 63/63 [==============================] - 82s 1s/step - loss: 1.2490 - accuracy: 0.5945
# Epoch 5/20
# 63/63 [==============================] - 83s 1s/step - loss: 0.7814 - accuracy: 0.7537
# Epoch 6/20
# 63/63 [==============================] - 82s 1s/step - loss: 0.4294 - accuracy: 0.8662
# Epoch 7/20
# 63/63 [==============================] - 82s 1s/step - loss: 0.2805 - accuracy: 0.9194
# Epoch 8/20
# 63/63 [==============================] - 82s 1s/step - loss: 0.1489 - accuracy: 0.9632
# Epoch 9/20
# 63/63 [==============================] - 82s 1s/step - loss: 0.1092 - accuracy: 0.9706
# Epoch 10/20
# ...

# %%
history = model.evaluate(trainImageGenerator)
# Out:
# 63/63 [==============================] - 23s 355ms/step - loss: 0.0076 - accuracy: 0.9975

# %% [markdown]
# ### Model accuracy on train dataset

# %%
print('Accuracy: {:.2f}%'.format(history[1] * 100))
print('Loss: {:.2f}%'.format(history[0] * 100))
# Out:
# Accuracy: 99.75%
# Loss: 0.76%

# %%
predictions = model.evaluate(testImageGenerator)
# Out:
# 24/24 [==============================] - 8s 311ms/step - loss: 0.7308 - accuracy: 0.9188

# %% [markdown]
# ### Model accuracy on test dataset

# %%
print('Accuracy: {:.2f}%'.format(predictions[1] * 100))
print('Loss: {:.2f}%'.format(predictions[0] * 100))
# Out:
# Accuracy: 91.88%
# Loss: 73.08%
