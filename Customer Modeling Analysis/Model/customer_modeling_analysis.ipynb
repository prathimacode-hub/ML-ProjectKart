# %% [markdown]
# #  Customers Modeling Analysis

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import string
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # LOADING THE DATASET

# %%
data = pd.read_csv('/kaggle/input/bank-customers/Churn Modeling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# **So our dataset contains different data types like int , object ,float.**

# %%
data.mean()
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569094e+07
# CreditScore        6.505288e+02
# Age                3.892180e+01
# Tenure             5.012800e+00
# Balance            7.648589e+04
# NumOfProducts      1.530200e+00
# HasCrCard          7.055000e-01
# IsActiveMember     5.151000e-01
# EstimatedSalary    1.000902e+05
# Exited             2.037000e-01
# dtype: float64

# %%
data.value_counts()
# Out:
# RowNumber  CustomerId  Surname     CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1          15634602    Hargrave    619          France     Female  42   2       0.00       1              1          1               101348.88        1         1
# 6671       15667932    Bellucci    758          Spain      Female  43   10      0.00       2              1          1               55313.44         0         1
# 6664       15766185    She         850          Germany    Male    31   4       146587.30  1              1          1               89874.82         0         1
# 6665       15667632    Birdseye    703          France     Female  42   7       0.00       2              0          1               72500.68         0         1
# 6666       15599024    Hope        506          Spain      Male    32   8       0.00       2              0          1               182692.80        0         1
#                                                                                                                                                                ..
# 3334       15599078    Yang        619          Germany    Female  41   5       92467.58   1              1          0               38270.47         0         1
# 3335       15702300    Walker      671          France     Male    27   5       0.00       2              0          0               120893.07        0         1
# 3336       15660735    T'ang       581          Spain      Female  31   6       0.00       2              1          0               188377.21        0         1
# 3337       15671390    Chukwukere  690          Spain      Male    36   10      0.00       2              1          0               55902.93         0         1
# 10000      15628319    Walker      792          France     Female  28   4       130142.79  1              1          0               38190.78         0         1
# Length: 10000, dtype: int64

# %% [markdown]
# **Checking Null Values**

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# **So our dataset contains 10000 rows and 14 columns**

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001384 -0.027094
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.012797  0.118533
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %% [markdown]
# **HEATMAP**
#
# **A heatmap is a graphical representation of data that uses a system of color-coding to represent different values. Heatmaps are used in various forms of analytics but are most commonly used to show user behaviour on specific webpages or webpage templates.**

# %%
plt.figure(figsize = (16,10))

sns.heatmap(data.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **HISTOGRAM**
#
# **A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis gives information about frequency.**

# %%
data.hist(figsize=(18,12))
plt.show()

# %% [markdown]
# **SCATTER PLOT**
#
# **A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.**

# %%
sns.scatterplot(x='Balance', y= 'CreditScore', data=data)
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='CreditScore'>

# %% [markdown]
# **PAIRPLOT**
#
# **A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.**

# %%
sns.set_style("whitegrid") 
mean_col = ['RowNumber','Gender','Age','Tenure','Balance','Exited']

sns.pairplot(data[mean_col],palette='Accent')

# %% [markdown]
# **RELPLOT**
#
# **This is a figure-level function for visualizing statistical relationships using two common approaches: scatter plots and line plots. ... relplot() combines a FacetGrid with one of two axes-level functions: scatterplot() (with kind="scatter" ; the default)**

# %%
sns.relplot(x='Age', y= 'CreditScore', data=data)

# %% [markdown]
# **JOINTPLOT**
#
# **Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins. This plot is a convenience class that wraps JointGrid.**

# %%
sns.jointplot(x='Balance', y= 'CreditScore', data=data)

# %% [markdown]
# **KDE PLOT (DENSITY PLOT)**
#
# **KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.**

# %%
plt.style.use("ggplot")
plt.figure(figsize=(14,8))
plt.xlabel('Balance')
plt.ylabel('CreditScore')
sns.kdeplot(data['Balance'],shade=True,color='blue')
plt.show()

# %% [markdown]
# **BARPLOT**
#
# **A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.**

# %%
plt.style.use("default")
sns.barplot(x="Balance", y="CreditScore",data=data[179:190])
plt.title("Balance vs CreditScore",fontsize=15)
plt.xlabel("Balance")
plt.ylabel("CreditScore")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="EstimatedSalary", y="CreditScore",data=data[183:190])
plt.title("EstimatedSalary vs CreditScore",fontsize=15)
plt.xlabel("EstimatedSalary")
plt.ylabel("CreditScore")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Tenure", y="Balance",data=data[170:190])
plt.title("Tenure vs Balance",fontsize=15)
plt.xlabel("Tenure")
plt.ylabel("Balance")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="HasCrCard", y="NumOfProducts",data=data[160:190])
plt.title("HasCrCard vs NumOfProducts",fontsize=15)
plt.xlabel("HasCrCard")
plt.ylabel("NumOfProducts")
plt.show()

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602     1115          619          0       0   42
# 1             2    15647311     1177          608          2       0   41
# 2             3    15619304     2040          502          0       0   42
# 3             4    15701354      289          699          0       0   39
# 4             5    15737888     1822          850          2       0   43
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996    15606229     1999          771          0       1   39
# 9996       9997    15569892     1336          516          0       1   35
# 9997       9998    15584532     1570          709          0       0   36
# 9998       9999    15682355     2345          772          1       1   42
# 9999      10000    15628319     2751          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
#drop the columns as it is no longer required
X = data.drop('Geography',axis=1)
y = data['Geography']

# %% [markdown]
# # TRAINING AND TESTING DATA

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(len(X_test))
print(len(X_train))
print(len(y_test))
print(len(y_train))
# Out:
# 2000
# 8000
# 2000
# 8000

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # ANN

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))

# Adding the second hidden layer
classifier.add(Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform"))

# Adding the output layer
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train,y_train,batch_size = 10,
    epochs=200,
)
# Out:
# Epoch 1/200
# 800/800 [==============================] - 2s 1ms/step - loss: 0.6369 - accuracy: 0.2456
# Epoch 2/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.2429
# Epoch 3/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5721 - accuracy: 0.2416
# Epoch 4/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5697 - accuracy: 0.2496
# Epoch 5/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.2400
# Epoch 6/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5621 - accuracy: 0.2531
# Epoch 7/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5506 - accuracy: 0.2475
# Epoch 8/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5659 - accuracy: 0.2445
# Epoch 9/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5649 - accuracy: 0.2392
# Epoch 10/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5686 - accuracy: 0.2326
# Epoch 11/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.2342
# Epoch 12/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5558 - accuracy: 0.2414
# Epoch 13/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.2380
# Epoch 14/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.2514
# Epoch 15/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.2495
# Epoch 16/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5521 - accuracy: 0.2346
# Epoch 17/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5490 - accuracy: 0.2498
# Epoch 18/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5615 - accuracy: 0.2474
# Epoch 19/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5697 - accuracy: 0.2437
# Epoch 20/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5666 - accuracy: 0.2499
# Epoch 21/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5687 - accuracy: 0.2471
# Epoch 22/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.2439
# Epoch 23/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5689 - accuracy: 0.2509
# Epoch 24/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5652 - accuracy: 0.2412
# Epoch 25/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.2495
# Epoch 26/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5527 - accuracy: 0.2443
# Epoch 27/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5553 - accuracy: 0.2469
# Epoch 28/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.2505
# Epoch 29/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5503 - accuracy: 0.2460
# Epoch 30/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.2431
# Epoch 31/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5615 - accuracy: 0.2445
# Epoch 32/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5669 - accuracy: 0.2406
# Epoch 33/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5576 - accuracy: 0.2442
# Epoch 34/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.2467
# Epoch 35/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.2366
# Epoch 36/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.2446
# Epoch 37/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5598 - accuracy: 0.2409
# Epoch 38/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.2566
# Epoch 39/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5588 - accuracy: 0.2413
# Epoch 40/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5549 - accuracy: 0.2493
# Epoch 41/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5722 - accuracy: 0.2509
# Epoch 42/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.2418
# Epoch 43/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5753 - accuracy: 0.2462
# Epoch 44/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5637 - accuracy: 0.2396
# Epoch 45/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.2454
# Epoch 46/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.2445
# Epoch 47/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.2472
# Epoch 48/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5541 - accuracy: 0.2444
# Epoch 49/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.2462
# Epoch 50/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.2375
# Epoch 51/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.2403
# Epoch 52/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5531 - accuracy: 0.2444
# Epoch 53/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5549 - accuracy: 0.2491
# Epoch 54/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.2482
# Epoch 55/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5682 - accuracy: 0.2408
# Epoch 56/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.2433
# Epoch 57/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.2429
# Epoch 58/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.2463
# Epoch 59/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.2428
# Epoch 60/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.2463
# Epoch 61/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.2449
# Epoch 62/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5456 - accuracy: 0.2482
# Epoch 63/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5468 - accuracy: 0.2372
# Epoch 64/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.2390
# Epoch 65/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5171 - accuracy: 0.2507
# Epoch 66/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.2493
# Epoch 67/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.2559
# Epoch 68/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.2475
# Epoch 69/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.2460
# Epoch 70/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.2453
# Epoch 71/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5240 - accuracy: 0.2491
# Epoch 72/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5700 - accuracy: 0.2526
# Epoch 73/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5451 - accuracy: 0.2501
# Epoch 74/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.2436
# Epoch 75/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.2541
# Epoch 76/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5606 - accuracy: 0.2427
# Epoch 77/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.2510
# Epoch 78/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5091 - accuracy: 0.2604
# Epoch 79/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5219 - accuracy: 0.2548
# Epoch 80/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5183 - accuracy: 0.2548
# Epoch 81/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5205 - accuracy: 0.2521
# Epoch 82/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.2515
# Epoch 83/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5273 - accuracy: 0.2540
# Epoch 84/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.2637
# Epoch 85/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5415 - accuracy: 0.2535
# Epoch 86/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.2501
# Epoch 87/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.2477
# Epoch 88/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.2575
# Epoch 89/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5161 - accuracy: 0.2541
# Epoch 90/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5459 - accuracy: 0.2622
# Epoch 91/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.2588
# Epoch 92/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5106 - accuracy: 0.2545
# Epoch 93/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5094 - accuracy: 0.2584
# Epoch 94/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5093 - accuracy: 0.2665
# Epoch 95/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.2636
# Epoch 96/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.2549
# Epoch 97/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.2534
# Epoch 98/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5192 - accuracy: 0.2606
# Epoch 99/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.2566
# Epoch 100/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.2609
# Epoch 101/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.2506
# Epoch 102/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5099 - accuracy: 0.2596
# Epoch 103/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.2647
# Epoch 104/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.2618
# Epoch 105/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.2820
# Epoch 106/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.2570
# Epoch 107/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.2644
# Epoch 108/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5187 - accuracy: 0.2713
# Epoch 109/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.2791
# Epoch 110/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.2653
# Epoch 111/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.2621
# Epoch 112/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5007 - accuracy: 0.2581
# Epoch 113/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.2754
# Epoch 114/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.2657
# Epoch 115/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5223 - accuracy: 0.2577
# Epoch 116/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.2707
# Epoch 117/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.2621
# Epoch 118/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5165 - accuracy: 0.2645
# Epoch 119/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.2690
# Epoch 120/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5210 - accuracy: 0.2599
# Epoch 121/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.2558
# Epoch 122/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5232 - accuracy: 0.2594
# Epoch 123/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4997 - accuracy: 0.2691
# Epoch 124/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.2640
# Epoch 125/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.2607
# Epoch 126/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5207 - accuracy: 0.2652
# Epoch 127/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5289 - accuracy: 0.2663
# Epoch 128/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5245 - accuracy: 0.2544
# Epoch 129/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.2645
# Epoch 130/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5126 - accuracy: 0.2624
# Epoch 131/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5283 - accuracy: 0.2683
# Epoch 132/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5160 - accuracy: 0.2523
# Epoch 133/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5193 - accuracy: 0.2584
# Epoch 134/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.2720
# Epoch 135/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5269 - accuracy: 0.2780
# Epoch 136/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5054 - accuracy: 0.2678
# Epoch 137/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5008 - accuracy: 0.2675
# Epoch 138/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.2705
# Epoch 139/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5236 - accuracy: 0.2744
# Epoch 140/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.2606
# Epoch 141/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5247 - accuracy: 0.2766
# Epoch 142/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5122 - accuracy: 0.2583
# Epoch 143/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5106 - accuracy: 0.2723
# Epoch 144/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5231 - accuracy: 0.2576
# Epoch 145/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5154 - accuracy: 0.2742
# Epoch 146/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5126 - accuracy: 0.2627
# Epoch 147/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5146 - accuracy: 0.2646
# Epoch 148/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5139 - accuracy: 0.2650
# Epoch 149/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.2684
# Epoch 150/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.2565
# Epoch 151/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.2760
# Epoch 152/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5261 - accuracy: 0.2682
# Epoch 153/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5233 - accuracy: 0.2609
# Epoch 154/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5216 - accuracy: 0.2628
# Epoch 155/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5296 - accuracy: 0.2750
# Epoch 156/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4995 - accuracy: 0.2621
# Epoch 157/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5101 - accuracy: 0.2708
# Epoch 158/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.2705
# Epoch 159/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4950 - accuracy: 0.2639
# Epoch 160/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5262 - accuracy: 0.2686
# Epoch 161/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5027 - accuracy: 0.2741
# Epoch 162/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4993 - accuracy: 0.2658
# Epoch 163/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5222 - accuracy: 0.2730
# Epoch 164/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.2692
# Epoch 165/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5149 - accuracy: 0.2601
# Epoch 166/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5078 - accuracy: 0.2670
# Epoch 167/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5238 - accuracy: 0.2697
# Epoch 168/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.2789
# Epoch 169/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5239 - accuracy: 0.2768
# Epoch 170/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5199 - accuracy: 0.2609
# Epoch 171/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5287 - accuracy: 0.2713
# Epoch 172/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5230 - accuracy: 0.2543
# Epoch 173/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.2615
# Epoch 174/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5202 - accuracy: 0.2716
# Epoch 175/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.2669
# Epoch 176/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5203 - accuracy: 0.2638
# Epoch 177/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5208 - accuracy: 0.2692
# Epoch 178/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5118 - accuracy: 0.2683
# Epoch 179/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5123 - accuracy: 0.2621
# Epoch 180/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.2673
# Epoch 181/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5247 - accuracy: 0.2701
# Epoch 182/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5080 - accuracy: 0.2646
# Epoch 183/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5177 - accuracy: 0.2706
# Epoch 184/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5212 - accuracy: 0.2736
# Epoch 185/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5168 - accuracy: 0.2711
# Epoch 186/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5113 - accuracy: 0.2526
# Epoch 187/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5210 - accuracy: 0.2801
# Epoch 188/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5293 - accuracy: 0.2728
# Epoch 189/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5148 - accuracy: 0.2754
# Epoch 190/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5230 - accuracy: 0.2831
# Epoch 191/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.2689
# Epoch 192/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5095 - accuracy: 0.2671
# Epoch 193/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5225 - accuracy: 0.2722
# Epoch 194/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4962 - accuracy: 0.2621
# Epoch 195/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5107 - accuracy: 0.2790
# Epoch 196/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5297 - accuracy: 0.2647
# Epoch 197/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5269 - accuracy: 0.2604
# Epoch 198/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5083 - accuracy: 0.2742
# Epoch 199/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.2696
# Epoch 200/200
# 800/800 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.2683

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([[0.60549307],
#        [0.96074235],
#        [0.4829654 ],
#        ...,
#        [0.8713349 ],
#        [0.70485085],
#        [0.6109684 ]], dtype=float32)

# %%
print((y_pred > 0.5))
# Out:
# [[ True]
#  [ True]
#  [False]
#  ...
#  [ True]
#  [ True]
#  [ True]]

# %%
from tensorflow.keras.utils import plot_model
plot_model(classifier, show_shapes = True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602     1115          619          0       0   42
# 1             2    15647311     1177          608          2       0   41
# 2             3    15619304     2040          502          0       0   42
# 3             4    15701354      289          699          0       0   39
# 4             5    15737888     1822          850          2       0   43
# ...         ...         ...      ...          ...        ...     ...  ...
# 9995       9996    15606229     1999          771          0       1   39
# 9996       9997    15569892     1336          516          0       1   35
# 9997       9998    15584532     1570          709          0       0   36
# 9998       9999    15682355     2345          772          1       1   42
# 9999      10000    15628319     2751          792          0       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 84
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("Mean Absolute Error:\n",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error:
#  0.6903115934085704
# Mean Absolute Error:
#  0.7240012141466141

# %%
classifier.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 0s 998us/step - loss: 0.5976 - accuracy: 0.2855
# [0.597600519657135, 0.2854999899864197]

# %% [markdown]
# # **Thank You**
