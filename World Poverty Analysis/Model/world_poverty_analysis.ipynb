# %% [markdown]
# # World Poverty Analysis
#
# ![](https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/23-06-2021_WFP_Madagascar.jpg/image1170x530cropped.jpg)

# %% [markdown]
# ### Contents
# 1. Abstract
# 2. Dataset
# 3. Goal
# 4. Importing required libraries and Dataset
# 5. Data Analysis
#     * Which Country is having Highest Poverty in Urban Areas.
#     * Which Country is having Highest and Lowest Population suffering from Poverty.
#     * What is the Intensity of Deprivation in Asian Countries.
#     * Which 10 Countries are the Poorest Countries.
#     * Which Countries’ Rural Population is having highest Poverty Index in the World.
#     * Analyzing Poverty in Afghanistan.
#     * What is the Difference between India and Afghanistan in terms of Poverty Index.
# 6. Conclusion

# %% [markdown]
# ### Abstract
# At the dawn of the 21st century we are still a long way from achieving what has eluded humanity for thousands of years, a world free from hunger and poverty. The past thirty years, however, have brought us closer to reaching this goal in a large part of the developing world. The lives of millions have been transformed at a pace unparalleled in human history and to an extent that would have seemed unthinkable only a generation ago.
#
# However, there is no room for complacency. Even today, close to 1.2 billion people - a fifth of the world's population - continue to live in conditions of abject poverty. Almost 800 million people in the developing world are chronically hungry. A basic right, the right to adequate and nutritious food, which most people take for granted, remains a distant dream for those who fight with food shortages every day of their lives. The presence of deep poverty and hunger on such a vast scale in a world of apparent opulence is a moral outrage.
#
# What is encouraging is that the international community has adopted the reduction of poverty and hunger eradication as overarching goals for development. Starting in the early 1990s, targets have been agreed upon for the reduction of poverty in its various forms and dimensions. Goals have been set for reducing poverty, raising school enrolment, moving towards gender equality, cutting infant and maternal mortality, improving access to reproductive health services, and adopting national strategies for sustainable development. In addition, at the World Food Summit, held in Rome in 1996, all nations committed themselves to the goal of halving the number of undernourished people from around 800 million to 400 million by 2015. Together, these targets have been adopted in the Millennium Development Goals which offer the promise of making the world a better place for the whole of humanity.
#
# The dimensions of hunger and malnutrition are alarming and cannot leave anyone indifferent. An estimated 174 million under-five children in the developing world were malnourished in 1996-98, and 6.6 million out of 12.2 million deaths among children in that age group are associated with malnutrition.
#
# Hunger is an important cause as well as an effect of poverty. The effects of hunger go beyond its terrible toll on those who suffer from it. Hunger has substantial economic costs for individuals, families and whole societies. Labour, often the only asset of the poor, is devalued for the hungry. Mental and physical health is compromised by lack of food, cutting productivity, output and the wages that people earn. Chronically hungry people cannot accumulate the financial or human capital which would allow them to escape poverty. And hunger has an inter-generational dimension, with undernourished mothers giving birth to underweight children. In societies where hunger is widespread, economic growth, an essential element in sustainable poverty reduction, is severely compromised.
#
# ### Dataset
# In this project the datasets that I have used are collected from Kaggle. Here are the links :
# 1. Kiva crowdfunding dataset : https://www.kaggle.com/kiva/data-science-for-good-kiva-crowdfunding
# 2. Multidimensional poverty measures : https://www.kaggle.com/ophi/mpi
# 3. World population : https://www.kaggle.com/walla2ae/world-population

# %% [markdown]
# ### Goal
# The goal of this project is to find out these following problem statements -
#
# > * a.	Which Country is having Highest Poverty in Urban Areas.
# > * b.	Which Country is having Highest and Lowest Population suffering from Poverty.
# > * c.	What is the Intensity of Deprivation in Asian Countries.
# > * d.	Which 10 Countries are the Poorest Countries.
# > * e.	Which Countries’ Rural Population is having highest Poverty Index in the World.
# > * f.	Analyzing Poverty in Afghanistan.
# > * g.	What is the Difference between India and Afghanistan in terms of Poverty Index.

# %% [markdown]
# ### Let's start with importing the libraries to be used throughout the notebook.

# %%
#importing the necessary libraries

#for mathematical opeartions and data manipulation
import numpy as np
import pandas as pd

#for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns

#warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Now let's read the datasets that we have

# %%
#Reading the dataset
data_nat = pd.read_csv("MPI_national.csv")
data_subnat = pd.read_csv("MPI_subnational.csv")

#Displaying the shape of both the datasets
print("The shape of MPI_national dataset is: ",data_nat.shape)
print("The shape of MPI_subnational is: ",data_subnat.shape)
# Out:
# The shape of MPI_national dataset is:  (102, 8)
# The shape of MPI_subnational is:  (984, 8)

# %% [markdown]
# ### Let's check the data contained in the two datasets

# %%
#The first five rows of the MPI_national dataset
data_nat.head()
# Out:
#    ISO     Country  MPI Urban  Headcount Ratio Urban  \
# 0  KAZ  Kazakhstan      0.000                    0.0
# 1  SRB      Serbia      0.000                    0.1
# 2  KGZ  Kyrgyzstan      0.000                    0.1
# 3  TUN     Tunisia      0.000                    0.1
# 4  ARM     Armenia      0.001                    0.2
#
#    Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 0                            33.3      0.000                   0.09
# 1                            41.4      0.002                   0.50
# 2                            40.2      0.003                   0.70
# 3                            35.6      0.012                   3.18
# 4                            33.3      0.001                   0.39
#
#    Intensity of Deprivation Rural
# 0                            33.3
# 1                            40.3
# 2                            37.1
# 3                            38.7
# 4                            36.9

# %% [markdown]
# 1. MPI Urban   -   MPI stands for Multidimensional Poverty Index(It is the weighted average number of deprivations poor poeple experience at the same time)
#
#
# 2. HeadcountRatio Urban  -   It is the proportions of the population that exists below the poverty line.
#
#
# 3. Intensity of Deprivation Urban  -  Average percentage of deprivation experienced by people in multidimensional poverty.

# %%
# The first five rows of the MPI_subnational dataset
data_subnat.head()
# Out:
#   ISO country code      Country Sub-national region World region  \
# 0              AFG  Afghanistan          Badakhshan   South Asia
# 1              AFG  Afghanistan             Badghis   South Asia
# 2              AFG  Afghanistan             Baghlan   South Asia
# 3              AFG  Afghanistan               Balkh   South Asia
# 4              AFG  Afghanistan              Bamyan   South Asia
#
#    MPI National  MPI Regional  Headcount Ratio Regional  \
# 0         0.295         0.387                      67.5
# 1         0.295         0.466                      79.3
# 2         0.295         0.300                      59.7
# 3         0.295         0.301                      55.7
# 4         0.295         0.325                      61.0
#
#    Intensity of deprivation Regional
# 0                               57.3
# 1                               58.8
# 2                               50.3
# 3                               54.1
# 4                               53.3

# %% [markdown]
# ## Data Analysis
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It can also help determine if the statistical techniques you are considering for data analysis are appropriate.

# %% [markdown]
# ### a. Which country is having highest poverty in Urban Areas

# %%
#maximum Headcount ratio of Urban Areas
data_nat['Headcount Ratio Urban'].max()
# Out:
# 82.5

# %%
#Looking at the data when Headcount Ratio Urban is equal to 82.5
data_nat[data_nat['Headcount Ratio Urban']==82.5]
# Out:
#      ISO      Country  MPI Urban  Headcount Ratio Urban  \
# 101  SSD  South Sudan      0.459                   82.5
#
#      Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 101                            55.7      0.591                   94.0
#
#      Intensity of Deprivation Rural
# 101                            62.8

# %% [markdown]
# **Observation :** South Sudan is the country which has the highest number of people falling below the poverty line. So, it is country having highest poverty in Urban Areas.
#
# ******************

# %% [markdown]
# ### b. Which Country is having Highest and Lowest Population suffering from Poverty.

# %%
#we created a new column which contain Headcount Ratio of both Urban as well as Rural Area
data_nat['Total Headcount Ratio'] = data_nat['Headcount Ratio Urban']+data_nat['Headcount Ratio Rural']

# %%
#Returns the country having maximum HeadCount Ratio
data_nat[data_nat['Total Headcount Ratio']==data_nat['Total Headcount Ratio'].max()] [['Country']]
# Out:
#          Country
# 101  South Sudan

# %%
#Returns the country having minimum Headcount Ratio
data_nat[data_nat['Total Headcount Ratio']==data_nat['Total Headcount Ratio'].min()] [['Country']]
# Out:
#       Country
# 0  Kazakhstan

# %% [markdown]
# **Observation :**
# 1. South Sudan is having highest population suffering from poverty.
#
# 2. kazakhstan is having lowest population suffering from poverty.
#
# -----------------------

# %% [markdown]
# ### c. What is the Intensity of Deprivation in Asian Countries.

# %%
#merges both the datasets together on Country column
data = pd.merge(data_nat,data_subnat, on='Country',how='outer')

# %%
#Checking the head of the newly merged dataset
data.head()
# Out:
#    ISO     Country  MPI Urban  Headcount Ratio Urban  \
# 0  KAZ  Kazakhstan      0.000                    0.0
# 1  SRB      Serbia      0.000                    0.1
# 2  KGZ  Kyrgyzstan      0.000                    0.1
# 3  TUN     Tunisia      0.000                    0.1
# 4  ARM     Armenia      0.001                    0.2
#
#    Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 0                            33.3      0.000                   0.09
# 1                            41.4      0.002                   0.50
# 2                            40.2      0.003                   0.70
# 3                            35.6      0.012                   3.18
# 4                            33.3      0.001                   0.39
#
#    Intensity of Deprivation Rural  Total Headcount Ratio ISO country code  \
# 0                            33.3                   0.09              NaN
# 1                            40.3                   0.60              NaN
# 2                            37.1                   0.80              NaN
# 3                            38.7                   3.28              NaN
# 4                            36.9                   0.59              NaN
#
#   Sub-national region World region  MPI National  MPI Regional  \
# 0                 NaN          NaN           NaN           NaN
# 1                 NaN          NaN           NaN           NaN
# 2                 NaN          NaN           NaN           NaN
# 3                 NaN          NaN           NaN           NaN
# 4                 NaN          NaN           NaN           NaN
#
#    Headcount Ratio Regional  Intensity of deprivation Regional
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       NaN                                NaN
# 3                       NaN                                NaN
# 4                       NaN                                NaN

# %%
#Value counts for World Region
data['World region'].value_counts()
# Out:
# Sub-Saharan Africa             431
# Latin America and Caribbean    218
# East Asia and the Pacific      128
# Arab States                    115
# South Asia                      81
# Europe and Central Asia         11
# Name: World region, dtype: int64

# %% [markdown]
# We can notice that "Asia" is separated so, we combined all the regions of Asia together and replace them with "Asia".

# %%
data['World region'] = data['World region'].replace(('East Asia and the Pacific','South Asia','Europe and Central Asia'),('Asia'))

# %%
data['World region'].value_counts()
# Out:
# Sub-Saharan Africa             431
# Asia                           220
# Latin America and Caribbean    218
# Arab States                    115
# Name: World region, dtype: int64

# %%
data.tail()
# Out:
#       ISO      Country  MPI Urban  Headcount Ratio Urban  \
# 1003  SSD  South Sudan      0.459                   82.5
# 1004  SSD  South Sudan      0.459                   82.5
# 1005  SSD  South Sudan      0.459                   82.5
# 1006  SSD  South Sudan      0.459                   82.5
# 1007  SSD  South Sudan      0.459                   82.5
#
#       Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 1003                            55.7      0.591                   94.0
# 1004                            55.7      0.591                   94.0
# 1005                            55.7      0.591                   94.0
# 1006                            55.7      0.591                   94.0
# 1007                            55.7      0.591                   94.0
#
#       Intensity of Deprivation Rural  Total Headcount Ratio ISO country code  \
# 1003                            62.8                  176.5              SSD
# 1004                            62.8                  176.5              SSD
# 1005                            62.8                  176.5              SSD
# 1006                            62.8                  176.5              SSD
# 1007                            62.8                  176.5              SSD
#
#          Sub-national region        World region  MPI National  MPI Regional  \
# 1003  Western Bahr el Ghazal  Sub-Saharan Africa         0.557         0.491
# 1004                   Lakes  Sub-Saharan Africa         0.557         0.605
# 1005       Western Equatoria  Sub-Saharan Africa         0.557         0.456
# 1006       Central Equatoria  Sub-Saharan Africa         0.557         0.391
# 1007       Eastern Equatoria  Sub-Saharan Africa         0.557         0.561
#
#       Headcount Ratio Regional  Intensity of deprivation Regional
# 1003                      84.9                               57.9
# 1004                      96.9                               62.5
# 1005                      85.2                               53.5
# 1006                      75.6                               51.7
# 1007                      92.5                               60.7

# %%
'''We sorted the "Intensity of Deprivation" column in ascending order for only Asian Countries'''

data[data['World region']=='Asia']['Intensity of Deprivation Urban'].sort_values(ascending=True)
# Out:
# 26     33.9
# 27     33.9
# 28     33.9
# 29     33.9
# 30     33.9
#        ...
# 826    47.3
# 825    47.3
# 836    47.3
# 830    47.3
# 837    47.3
# Name: Intensity of Deprivation Urban, Length: 220, dtype: float64

# %% [markdown]
# **Observation :** The average percentage of deprivation in Asian Countries is between 40% to 48% percent.
#
# ------------------------------------

# %% [markdown]
# ### d.  Which 10 Countries are the Poorest Countries?

# %%
#grouped by country and aggregated by maximum of Total Headcount Ratio
d = data_nat.groupby('Country')['Total Headcount Ratio'].agg(max)

# %%
d = d.reset_index()

# %%
d.sort_values(by='Total Headcount Ratio',ascending=False).head(10).style.background_gradient(cmap='copper')
# Out:
# <style  type="text/css" >
#     #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row0_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row1_col1 {
#             background-color:  #aa6c45;
#             color:  #000000;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row2_col1 {
#             background-color:  #7f5033;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row3_col1 {
#             background-color:  #69422a;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row4_col1 {
#             background-color:  #5b3a25;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row5_col1 {
#             background-color:  #593824;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row6_col1 {
#             background-color:  #442b1b;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row7_col1 {
#             background-color:  #2e1d12;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row8_col1 {
#             background-color:  #1c120b;
#             color:  #f1f1f1;
#         }    #T_c3c20dfa_db06_11eb_be5d_165e49bf7454row9_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Total Headcount Ratio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row0" class="row_heading level0 row0" >81</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row0_col0" class="data row0 col0" >South Sudan</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row0_col1" class="data row0 col1" >176.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row1" class="row_heading level0 row1" >18</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row1_col0" class="data row1 col0" >Chad</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row1_col1" class="data row1 col1" >158.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row2" class="row_heading level0 row2" >79</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row2_col0" class="data row2 col0" >Somalia</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row2_col1" class="data row2 col1" >152.820000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row3" class="row_heading level0 row3" >67</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row3_col0" class="data row3 col0" >Niger</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row3_col1" class="data row3 col1" >150.090000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row4" class="row_heading level0 row4" >78</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row4_col0" class="data row4 col0" >Sierra Leone</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row4_col1" class="data row4 col1" >148.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row5" class="row_heading level0 row5" >17</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row5_col0" class="data row5 col0" >Central African Republic</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row5_col1" class="data row5 col1" >147.990000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row6" class="row_heading level0 row6" >50</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row6_col0" class="data row6 col0" >Liberia</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row6_col1" class="data row6 col1" >145.360000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row7" class="row_heading level0 row7" >30</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row7_col0" class="data row7 col0" >Ethiopia</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row7_col1" class="data row7 col1" >142.670000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row8" class="row_heading level0 row8" >13</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row8_col0" class="data row8 col0" >Burkina Faso</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row8_col1" class="data row8 col1" >140.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454level0_row9" class="row_heading level0 row9" >22</th>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row9_col0" class="data row9 col0" >Congo, Democratic Republic of the</td>
#                         <td id="T_c3c20dfa_db06_11eb_be5d_165e49bf7454row9_col1" class="data row9 col1" >136.780000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Observation :**
# The 10 most poorest countries are
# 1. South Sudan
# 2. Chad
# 3. Somalia
# 4. Niger
# 5. Sierra Leone
# 6. Central African Republic
# 7. Liberia
# 8. Ethiopia
# 9. Burkina Faso
# 10. Congo
#
# ***********************

# %% [markdown]
# ### e. Which Countries’ Rural Population is having highest Poverty Index in the World?

# %%
#Returns the country having highest MPI Rural
data[data['MPI Rural']==data['MPI Rural'].max()][['Country']]
# Out:
#     Country
# 938   Niger
# 939   Niger
# 940   Niger
# 941   Niger
# 942   Niger
# 943   Niger
# 944   Niger
# 945   Niger

# %% [markdown]
# **Observation :** Niger is the country whose Rural Population has the highest Poverty Index in the World.
#
# *********************

# %% [markdown]
# ### f. Analyzing Poverty in Afghanistan.

# %%
#Creates a new dataframe which contains poverty details of only Afghanistan
afg = data[data['Country']=='Afghanistan']
afg
# Out:
#      ISO      Country  MPI Urban  Headcount Ratio Urban  \
# 740  AFG  Afghanistan      0.132                   28.8
# 741  AFG  Afghanistan      0.132                   28.8
# 742  AFG  Afghanistan      0.132                   28.8
# 743  AFG  Afghanistan      0.132                   28.8
# 744  AFG  Afghanistan      0.132                   28.8
# 745  AFG  Afghanistan      0.132                   28.8
# 746  AFG  Afghanistan      0.132                   28.8
# 747  AFG  Afghanistan      0.132                   28.8
# 748  AFG  Afghanistan      0.132                   28.8
# 749  AFG  Afghanistan      0.132                   28.8
# 750  AFG  Afghanistan      0.132                   28.8
# 751  AFG  Afghanistan      0.132                   28.8
# 752  AFG  Afghanistan      0.132                   28.8
# 753  AFG  Afghanistan      0.132                   28.8
# 754  AFG  Afghanistan      0.132                   28.8
# 755  AFG  Afghanistan      0.132                   28.8
# 756  AFG  Afghanistan      0.132                   28.8
# 757  AFG  Afghanistan      0.132                   28.8
# 758  AFG  Afghanistan      0.132                   28.8
# 759  AFG  Afghanistan      0.132                   28.8
# 760  AFG  Afghanistan      0.132                   28.8
# 761  AFG  Afghanistan      0.132                   28.8
# 762  AFG  Afghanistan      0.132                   28.8
# 763  AFG  Afghanistan      0.132                   28.8
# 764  AFG  Afghanistan      0.132                   28.8
# 765  AFG  Afghanistan      0.132                   28.8
# 766  AFG  Afghanistan      0.132                   28.8
# 767  AFG  Afghanistan      0.132                   28.8
# 768  AFG  Afghanistan      0.132                   28.8
# 769  AFG  Afghanistan      0.132                   28.8
# 770  AFG  Afghanistan      0.132                   28.8
# 771  AFG  Afghanistan      0.132                   28.8
# 772  AFG  Afghanistan      0.132                   28.8
# 773  AFG  Afghanistan      0.132                   28.8
#
#      Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 740                            45.8      0.347                  64.66
# 741                            45.8      0.347                  64.66
# 742                            45.8      0.347                  64.66
# 743                            45.8      0.347                  64.66
# 744                            45.8      0.347                  64.66
# 745                            45.8      0.347                  64.66
# 746                            45.8      0.347                  64.66
# 747                            45.8      0.347                  64.66
# 748                            45.8      0.347                  64.66
# 749                            45.8      0.347                  64.66
# 750                            45.8      0.347                  64.66
# 751                            45.8      0.347                  64.66
# 752                            45.8      0.347                  64.66
# 753                            45.8      0.347                  64.66
# 754                            45.8      0.347                  64.66
# 755                            45.8      0.347                  64.66
# 756                            45.8      0.347                  64.66
# 757                            45.8      0.347                  64.66
# 758                            45.8      0.347                  64.66
# 759                            45.8      0.347                  64.66
# 760                            45.8      0.347                  64.66
# 761                            45.8      0.347                  64.66
# 762                            45.8      0.347                  64.66
# 763                            45.8      0.347                  64.66
# 764                            45.8      0.347                  64.66
# 765                            45.8      0.347                  64.66
# 766                            45.8      0.347                  64.66
# 767                            45.8      0.347                  64.66
# 768                            45.8      0.347                  64.66
# 769                            45.8      0.347                  64.66
# 770                            45.8      0.347                  64.66
# 771                            45.8      0.347                  64.66
# 772                            45.8      0.347                  64.66
# 773                            45.8      0.347                  64.66
#
#      Intensity of Deprivation Rural  Total Headcount Ratio ISO country code  \
# 740                            53.6                  93.46              AFG
# 741                            53.6                  93.46              AFG
# 742                            53.6                  93.46              AFG
# 743                            53.6                  93.46              AFG
# 744                            53.6                  93.46              AFG
# 745                            53.6                  93.46              AFG
# 746                            53.6                  93.46              AFG
# 747                            53.6                  93.46              AFG
# 748                            53.6                  93.46              AFG
# 749                            53.6                  93.46              AFG
# 750                            53.6                  93.46              AFG
# 751                            53.6                  93.46              AFG
# 752                            53.6                  93.46              AFG
# 753                            53.6                  93.46              AFG
# 754                            53.6                  93.46              AFG
# 755                            53.6                  93.46              AFG
# 756                            53.6                  93.46              AFG
# 757                            53.6                  93.46              AFG
# 758                            53.6                  93.46              AFG
# 759                            53.6                  93.46              AFG
# 760                            53.6                  93.46              AFG
# 761                            53.6                  93.46              AFG
# 762                            53.6                  93.46              AFG
# 763                            53.6                  93.46              AFG
# 764                            53.6                  93.46              AFG
# 765                            53.6                  93.46              AFG
# 766                            53.6                  93.46              AFG
# 767                            53.6                  93.46              AFG
# 768                            53.6                  93.46              AFG
# 769                            53.6                  93.46              AFG
# 770                            53.6                  93.46              AFG
# 771                            53.6                  93.46              AFG
# 772                            53.6                  93.46              AFG
# 773                            53.6                  93.46              AFG
#
#     Sub-national region World region  MPI National  MPI Regional  \
# 740          Badakhshan         Asia         0.295         0.387
# 741             Badghis         Asia         0.295         0.466
# 742             Baghlan         Asia         0.295         0.300
# 743               Balkh         Asia         0.295         0.301
# 744              Bamyan         Asia         0.295         0.325
# 745            Daykundi         Asia         0.295         0.313
# 746               Farah         Asia         0.295         0.319
# 747              Faryab         Asia         0.295         0.250
# 748              Ghazni         Asia         0.295         0.245
# 749                Ghor         Asia         0.295         0.384
# 750             Helmand         Asia         0.295         0.261
# 751               Herat         Asia         0.295         0.353
# 752             Jawzjan         Asia         0.295         0.293
# 753               Kabul         Asia         0.295         0.117
# 754            Kandahar         Asia         0.295         0.437
# 755              Kapisa         Asia         0.295         0.280
# 756               Khost         Asia         0.295         0.296
# 757             Kunarha         Asia         0.295         0.269
# 758              Kunduz         Asia         0.295         0.294
# 759             Laghman         Asia         0.295         0.369
# 760               Logar         Asia         0.295         0.187
# 761           Nangarhar         Asia         0.295         0.287
# 762              Nimroz         Asia         0.295         0.231
# 763           Nooristan         Asia         0.295         0.611
# 764             Paktika         Asia         0.295         0.137
# 765              Paktya         Asia         0.295         0.218
# 766            Panjsher         Asia         0.295         0.120
# 767              Parwan         Asia         0.295         0.294
# 768            Samangan         Asia         0.295         0.350
# 769           Sar-E-Pul         Asia         0.295         0.341
# 770              Takhar         Asia         0.295         0.361
# 771             Urozgan         Asia         0.295         0.624
# 772              Wardak         Asia         0.295         0.340
# 773               Zabul         Asia         0.295         0.175
#
#      Headcount Ratio Regional  Intensity of deprivation Regional
# 740                      67.5                               57.3
# 741                      79.3                               58.8
# 742                      59.7                               50.3
# 743                      55.7                               54.1
# 744                      61.0                               53.3
# 745                      65.1                               48.1
# 746                      61.4                               52.0
# 747                      49.4                               50.6
# 748                      47.4                               51.6
# 749                      74.6                               51.5
# 750                      61.8                               42.2
# 751                      63.3                               55.8
# 752                      60.9                               48.1
# 753                      25.3                               46.1
# 754                      72.1                               60.7
# 755                      53.6                               52.3
# 756                      57.8                               51.1
# 757                      58.3                               46.2
# 758                      60.5                               48.5
# 759                      70.4                               52.4
# 760                      41.4                               45.2
# 761                      54.9                               52.4
# 762                      45.4                               50.9
# 763                      93.7                               65.2
# 764                      28.1                               48.6
# 765                      45.2                               48.3
# 766                      25.8                               46.6
# 767                      58.6                               50.1
# 768                      64.3                               54.4
# 769                      67.8                               50.3
# 770                      65.1                               55.4
# 771                      94.5                               66.0
# 772                      67.9                               50.1
# 773                      34.6                               50.4

# %%
#checking for the subnational region which has highest MPI
afg[afg['MPI Regional']==afg['MPI Regional'].max()][['Sub-national region']]
# Out:
#     Sub-national region
# 771             Urozgan

# %%
afg.groupby('Sub-national region')['MPI Regional'].agg(max).sort_values(ascending=False)
# Out:
# Sub-national region
# Urozgan       0.624
# Nooristan     0.611
# Badghis       0.466
# Kandahar      0.437
# Badakhshan    0.387
# Ghor          0.384
# Laghman       0.369
# Takhar        0.361
# Herat         0.353
# Samangan      0.350
# Sar-E-Pul     0.341
# Wardak        0.340
# Bamyan        0.325
# Farah         0.319
# Daykundi      0.313
# Balkh         0.301
# Baghlan       0.300
# Khost         0.296
# Kunduz        0.294
# Parwan        0.294
# Jawzjan       0.293
# Nangarhar     0.287
# Kapisa        0.280
# Kunarha       0.269
# Helmand       0.261
# Faryab        0.250
# Ghazni        0.245
# Nimroz        0.231
# Paktya        0.218
# Logar         0.187
# Zabul         0.175
# Paktika       0.137
# Panjsher      0.120
# Kabul         0.117
# Name: MPI Regional, dtype: float64

# %%
afg.groupby('Sub-national region')['Headcount Ratio Regional'].agg(max).sort_values(ascending=False)
# Out:
# Sub-national region
# Urozgan       94.5
# Nooristan     93.7
# Badghis       79.3
# Ghor          74.6
# Kandahar      72.1
# Laghman       70.4
# Wardak        67.9
# Sar-E-Pul     67.8
# Badakhshan    67.5
# Daykundi      65.1
# Takhar        65.1
# Samangan      64.3
# Herat         63.3
# Helmand       61.8
# Farah         61.4
# Bamyan        61.0
# Jawzjan       60.9
# Kunduz        60.5
# Baghlan       59.7
# Parwan        58.6
# Kunarha       58.3
# Khost         57.8
# Balkh         55.7
# Nangarhar     54.9
# Kapisa        53.6
# Faryab        49.4
# Ghazni        47.4
# Nimroz        45.4
# Paktya        45.2
# Logar         41.4
# Zabul         34.6
# Paktika       28.1
# Panjsher      25.8
# Kabul         25.3
# Name: Headcount Ratio Regional, dtype: float64

# %%
afg.groupby('Sub-national region')['Intensity of deprivation Regional'].agg(max).sort_values(ascending=False)
# Out:
# Sub-national region
# Urozgan       66.0
# Nooristan     65.2
# Kandahar      60.7
# Badghis       58.8
# Badakhshan    57.3
# Herat         55.8
# Takhar        55.4
# Samangan      54.4
# Balkh         54.1
# Bamyan        53.3
# Nangarhar     52.4
# Laghman       52.4
# Kapisa        52.3
# Farah         52.0
# Ghazni        51.6
# Ghor          51.5
# Khost         51.1
# Nimroz        50.9
# Faryab        50.6
# Zabul         50.4
# Sar-E-Pul     50.3
# Baghlan       50.3
# Parwan        50.1
# Wardak        50.1
# Paktika       48.6
# Kunduz        48.5
# Paktya        48.3
# Daykundi      48.1
# Jawzjan       48.1
# Panjsher      46.6
# Kunarha       46.2
# Kabul         46.1
# Logar         45.2
# Helmand       42.2
# Name: Intensity of deprivation Regional, dtype: float64

# %% [markdown]
# **Observation :**
#
# Poverty in Afghanistan
# 1. The Rural population of Afghanistan has more proportion of people living under poverty line.
# 2. Urozgan is the sub national region in Afghanistan which is having highest MPI, Intensity of deprivation and Headcount Ratio.
# 3. Around 45% deprivation is experienced by Urban people and 53% deprivation is experienced by Rural people in Afghanistan.
#
# ****************************

# %% [markdown]
# ### g. What is the Difference between India and Afghanistan in terms of Poverty Index?

# %%
data_nat[data_nat['Country']=='India']
# Out:
#     ISO Country  MPI Urban  Headcount Ratio Urban  \
# 58  IND   India      0.064                   14.8
#
#     Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 58                            43.3       0.25                  53.49
#
#     Intensity of Deprivation Rural  Total Headcount Ratio
# 58                            46.7                  68.29

# %%
data_nat[data_nat['Country']=='Afghanistan']
# Out:
#     ISO      Country  MPI Urban  Headcount Ratio Urban  \
# 79  AFG  Afghanistan      0.132                   28.8
#
#     Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 79                            45.8      0.347                  64.66
#
#     Intensity of Deprivation Rural  Total Headcount Ratio
# 79                            53.6                  93.46

# %% [markdown]
# **Observation :**
# 1. The Poverty Index of Afghanistan is more than India in Urban as well as Rural.
#
# 2. The MPI Urban is double in Afghanistan than India and even the MPI Rural is far more in Afghanistan than India.
# *******************

# %% [markdown]
# ## Conclusion
# We have analyzed the dataset and depending on the problem statements we have concluded these following points -
# 1. South Sudan is the country which has the highest number of people falling below the poverty line. So, it is country having highest poverty in Urban Areas.
# 2. South Sudan is having highest population suffering from poverty.
# 3. Kazakhstan is having lowest population suffering from poverty.
# 4. The average percentage of deprivation in Asian Countries is between 40% to 48% percent.
# 5. The 10 most poorest countries are
#     1. South Sudan
#     2. Chad
#     3. Somalia
#     4. Niger
#     5. Sierra Leone
#     6. Central African Republic
#     7. Liberia
#     8. Ethiopia
#     9. Burkina Faso
#     10. Congo
# 6. Niger is the country whose Rural Population has the highest Poverty Index in the World.
# 7. Poverty in Afghanistan
#     1. The Rural population of Afghanistan has more proportion of people living under poverty line.
#     2. Urozgan is the sub national region in Afghanistan which is having highest MPI, Intensity of deprivation and Headcount Ratio.
#     3. Around 45% deprivation is experienced by Urban people and 53% deprivation is experienced by Rural people in Afghanistan.
# 8. The Poverty Index of Afghanistan is more than India in Urban as well as Rural.
# 9. The MPI Urban is double in Afghanistan than India and even the MPI Rural is far more in Afghanistan than India.
# *******************
