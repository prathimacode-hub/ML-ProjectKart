# %%
#import libraries
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import data
train_df = pd.read_csv("C:/Users/My/Desktop/churn analysis/train.csv")
test_df = pd.read_csv("C:/Users/My/Desktop/churn analysis/test.csv")

# %% [markdown]
# # Data inspection

# %%
train_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# 1                       ?    CID21329  ...         306.34
# 2                     Yes    CID12313  ...         516.16
# 3                     Yes     CID3793  ...          53.27
# 4                      No    xxxxxxxx  ...         113.13
#
#   avg_transaction_value avg_frequency_login_days points_in_wallet  \
# 0              53005.25                     17.0           781.75
# 1              12838.38                     10.0              NaN
# 2              21027.00                     22.0           500.69
# 3              25239.56                      6.0           567.66
# 4              24483.66                     16.0           663.06
#
#    used_special_discount  offer_application_preference  past_complaint  \
# 0                    Yes                           Yes              No
# 1                    Yes                            No             Yes
# 2                     No                           Yes             Yes
# 3                     No                           Yes             Yes
# 4                     No                           Yes             Yes
#
#       complaint_status                  feedback churn_risk_score
# 0       Not Applicable  Products always in Stock                2
# 1               Solved     Quality Customer Care                1
# 2  Solved in Follow-up              Poor Website                5
# 3             Unsolved              Poor Website                5
# 4               Solved              Poor Website                5
#
# [5 rows x 25 columns]

# %%
test_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0  fffe43004900440031003700300030003400    Alethia Meints   50      F
# 1  fffe43004900440031003900370037003300        Ming Lopez   41      M
# 2  fffe43004900440034003800360037003000  Carina Flannigan   31      F
# 3  fffe43004900440036003200370033003400      Kyung Wanner   64      M
# 4  fffe43004900440035003000370031003900       Enola Gatto   16      F
#
#   security_no region_category membership_category joining_date  \
# 0     OQJ1XAY         Village  Premium Membership   2015-11-02
# 1     OUQRPKO         Village     Gold Membership   2016-03-01
# 2     02J2RE7            Town   Silver Membership   2017-03-03
# 3     5YEQIF1            Town   Silver Membership   2017-08-18
# 4     100RYB5            Town       No Membership   2015-05-05
#
#   joined_through_referral referral_id  ... days_since_last_login  \
# 0                      No    xxxxxxxx  ...                    12
# 1                      No    xxxxxxxx  ...                    11
# 2                      No    xxxxxxxx  ...                    18
# 3                     Yes     CID8941  ...                  -999
# 4                     Yes     CID5690  ...                     6
#
#   avg_time_spent avg_transaction_value avg_frequency_login_days  \
# 0         386.26              40721.44                      7.0
# 1          37.80               9644.40                      9.0
# 2         215.36               3693.25                     21.0
# 3          44.57              36809.56                     11.0
# 4         349.88              40675.86                      8.0
#
#    points_in_wallet  used_special_discount  offer_application_preference  \
# 0        733.830000                    Yes                            No
# 1        726.000000                    Yes                            No
# 2        713.780000                    Yes                            No
# 3        744.970000                    Yes                            No
# 4        299.048351                     No                           Yes
#
#   past_complaint          complaint_status              feedback
# 0             No            Not Applicable  Poor Product Quality
# 1             No            Not Applicable          Poor Website
# 2            Yes       Solved in Follow-up   No reason specified
# 3            Yes  No Information Available          Too many ads
# 4            Yes       Solved in Follow-up          Poor Website
#
# [5 rows x 24 columns]

# %%
#shape of dataset 
print("shape of dataframe:", train_df.shape)
#data types 
print("\nVariable types:\n", train_df.dtypes.value_counts(),train_df.dtypes.value_counts().plot.pie())
plt.draw()
# Out:
# shape of dataframe: (36992, 25)
#
# Variable types:
#  object     19
# float64     3
# int64       3
# dtype: int64 AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#shape of dataset 
print("shape of dataframe:", test_df.shape)
#data types 
print("\nVariable types:\n", test_df.dtypes.value_counts(),test_df.dtypes.value_counts().plot.pie())
plt.draw()
# Out:
# shape of dataframe: (19919, 24)
#
# Variable types:
#  object     19
# float64     3
# int64       2
# dtype: int64 AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36992 entries, 0 to 36991
# Data columns (total 25 columns):
# customer_id                     36992 non-null object
# Name                            36992 non-null object
# age                             36992 non-null int64
# gender                          36992 non-null object
# security_no                     36992 non-null object
# region_category                 31564 non-null object
# membership_category             36992 non-null object
# joining_date                    36992 non-null object
# joined_through_referral         36992 non-null object
# referral_id                     36992 non-null object
# preferred_offer_types           36704 non-null object
# medium_of_operation             36992 non-null object
# internet_option                 36992 non-null object
# last_visit_time                 36992 non-null object
# days_since_last_login           36992 non-null int64
# avg_time_spent                  36992 non-null float64
# avg_transaction_value           36992 non-null float64
# avg_frequency_login_days        36992 non-null object
# points_in_wallet                33549 non-null float64
# used_special_discount           36992 non-null object
# offer_application_preference    36992 non-null object
# past_complaint                  36992 non-null object
# complaint_status                36992 non-null object
# feedback                        36992 non-null object
# churn_risk_score                36992 non-null int64
# dtypes: float64(3), int64(3), object(19)
# memory usage: 7.1+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19919 entries, 0 to 19918
# Data columns (total 24 columns):
# customer_id                     19919 non-null object
# Name                            19919 non-null object
# age                             19919 non-null int64
# gender                          19919 non-null object
# security_no                     19919 non-null object
# region_category                 16971 non-null object
# membership_category             19919 non-null object
# joining_date                    19919 non-null object
# joined_through_referral         19919 non-null object
# referral_id                     19919 non-null object
# preferred_offer_types           19760 non-null object
# medium_of_operation             19919 non-null object
# internet_option                 19919 non-null object
# last_visit_time                 19919 non-null object
# days_since_last_login           19919 non-null int64
# avg_time_spent                  19919 non-null float64
# avg_transaction_value           19919 non-null float64
# avg_frequency_login_days        19919 non-null object
# points_in_wallet                17956 non-null float64
# used_special_discount           19919 non-null object
# offer_application_preference    19919 non-null object
# past_complaint                  19919 non-null object
# complaint_status                19919 non-null object
# feedback                        19919 non-null object
# dtypes: float64(3), int64(2), object(19)
# memory usage: 3.6+ MB

# %% [markdown]
# # Data Cleaning

# %%
train_df = train_df.drop(['Name', 'referral_id'], axis=1)  # dropping unnecessary columns 
train_df
# Out:
#                                 customer_id  age gender security_no  \
# 0          fffe4300490044003600300030003800   18      F     XW0DQ7H
# 1      fffe43004900440032003100300035003700   32      F     5K0N3X1
# 2          fffe4300490044003100390032003600   44      F     1F2TCL3
# 3      fffe43004900440036003000330031003600   37      M     VJGJ33N
# 4      fffe43004900440031003900350030003600   31      F     SVZXCWB
# ...                                     ...  ...    ...         ...
# 36987  fffe43004900440035003500390036003100   46      F     6F51HFO
# 36988  fffe43004900440033003500380036003600   29      F     21KSM8Y
# 36989      fffe4300490044003500330034003100   23      F     XK1IM9H
# 36990  fffe43004900440031003200390039003000   53      M     K6VTP1Z
# 36991  fffe43004900440033003600340034003200   35      M     LBX0GLR
#
#       region_category  membership_category joining_date  \
# 0             Village  Platinum Membership   2017-08-17
# 1                City   Premium Membership   2017-08-28
# 2                Town        No Membership   2016-11-11
# 3                City        No Membership   2016-10-29
# 4                City        No Membership   2017-09-12
# ...               ...                  ...          ...
# 36987             NaN     Basic Membership   2017-09-21
# 36988            Town     Basic Membership   2016-06-27
# 36989             NaN     Basic Membership   2016-09-11
# 36990         Village  Platinum Membership   2017-06-15
# 36991            Town    Silver Membership   2015-10-23
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                          No     Gift Vouchers/Coupons                   ?
# 1                           ?     Gift Vouchers/Coupons             Desktop
# 2                         Yes     Gift Vouchers/Coupons             Desktop
# 3                         Yes     Gift Vouchers/Coupons             Desktop
# 4                          No  Credit/Debit Card Offers          Smartphone
# ...                       ...                       ...                 ...
# 36987                      No  Credit/Debit Card Offers             Desktop
# 36988                      No            Without Offers          Smartphone
# 36989                     Yes     Gift Vouchers/Coupons             Desktop
# 36990                      No     Gift Vouchers/Coupons          Smartphone
# 36991                      No     Gift Vouchers/Coupons             Desktop
#
#        ... avg_time_spent avg_transaction_value  avg_frequency_login_days  \
# 0      ...     300.630000              53005.25                      17.0
# 1      ...     306.340000              12838.38                      10.0
# 2      ...     516.160000              21027.00                      22.0
# 3      ...      53.270000              25239.56                       6.0
# 4      ...     113.130000              24483.66                      16.0
# ...    ...            ...                   ...                       ...
# 36987  ...    -650.682759              27277.68                       6.0
# 36988  ...    -638.123421              11069.71                      28.0
# 36989  ...     154.940000              38127.56                     Error
# 36990  ...     482.610000               2378.86                      20.0
# 36991  ...      79.180000               2189.68                     Error
#
#        points_in_wallet  used_special_discount offer_application_preference  \
# 0            781.750000                    Yes                          Yes
# 1                   NaN                    Yes                           No
# 2            500.690000                     No                          Yes
# 3            567.660000                     No                          Yes
# 4            663.060000                     No                          Yes
# ...                 ...                    ...                          ...
# 36987        639.510000                     No                          Yes
# 36988        527.990000                    Yes                           No
# 36989        680.470000                     No                          Yes
# 36990        197.264414                    Yes                          Yes
# 36991        719.970000                    Yes                           No
#
#        past_complaint          complaint_status                  feedback  \
# 0                  No            Not Applicable  Products always in Stock
# 1                 Yes                    Solved     Quality Customer Care
# 2                 Yes       Solved in Follow-up              Poor Website
# 3                 Yes                  Unsolved              Poor Website
# 4                 Yes                    Solved              Poor Website
# ...               ...                       ...                       ...
# 36987             Yes  No Information Available       No reason specified
# 36988              No            Not Applicable     Poor Customer Service
# 36989             Yes                  Unsolved              Poor Website
# 36990              No            Not Applicable       No reason specified
# 36991              No            Not Applicable     Quality Customer Care
#
#       churn_risk_score
# 0                    2
# 1                    1
# 2                    5
# 3                    5
# 4                    5
# ...                ...
# 36987                4
# 36988                5
# 36989                4
# 36990                3
# 36991                2
#
# [36992 rows x 23 columns]

# %%
test_df = test_df.drop(['Name', 'referral_id'], axis=1)
test_df
# Out:
#                                 customer_id  age gender security_no  \
# 0      fffe43004900440031003700300030003400   50      F     OQJ1XAY
# 1      fffe43004900440031003900370037003300   41      M     OUQRPKO
# 2      fffe43004900440034003800360037003000   31      F     02J2RE7
# 3      fffe43004900440036003200370033003400   64      M     5YEQIF1
# 4      fffe43004900440035003000370031003900   16      F     100RYB5
# ...                                     ...  ...    ...         ...
# 19914  fffe43004900440035003600330037003800   12      M     2V0HA0O
# 19915  fffe43004900440032003900370037003100   40      F     VJGQD6Q
# 19916  fffe43004900440036003100310036003700   55      M     ADE7LWA
# 19917  fffe43004900440034003200330033003600   17      F     A35KUBS
# 19918  fffe43004900440036003200340030003100   20      M     IPJKJJV
#
#       region_category membership_category joining_date  \
# 0             Village  Premium Membership   2015-11-02
# 1             Village     Gold Membership   2016-03-01
# 2                Town   Silver Membership   2017-03-03
# 3                Town   Silver Membership   2017-08-18
# 4                Town       No Membership   2015-05-05
# ...               ...                 ...          ...
# 19914             NaN     Gold Membership   2015-01-25
# 19915         Village       No Membership   2017-12-31
# 19916            Town       No Membership   2015-09-09
# 19917            City   Silver Membership   2016-04-17
# 19918            Town  Premium Membership   2017-10-30
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                          No            Without Offers          Smartphone
# 1                          No            Without Offers             Desktop
# 2                          No     Gift Vouchers/Coupons                Both
# 3                         Yes  Credit/Debit Card Offers                   ?
# 4                         Yes            Without Offers          Smartphone
# ...                       ...                       ...                 ...
# 19914                      No            Without Offers             Desktop
# 19915                     Yes            Without Offers             Desktop
# 19916                      No  Credit/Debit Card Offers             Desktop
# 19917                     Yes  Credit/Debit Card Offers          Smartphone
# 19918                     Yes     Gift Vouchers/Coupons                Both
#
#        ... days_since_last_login avg_time_spent  avg_transaction_value  \
# 0      ...                    12         386.26               40721.44
# 1      ...                    11          37.80                9644.40
# 2      ...                    18         215.36                3693.25
# 3      ...                  -999          44.57               36809.56
# 4      ...                     6         349.88               40675.86
# ...    ...                   ...            ...                    ...
# 19914  ...                    16         103.57               46279.35
# 19915  ...                    21          63.19               23466.26
# 19916  ...                    18          68.72               17903.75
# 19917  ...                     3         119.54               14057.09
# 19918  ...                     8         505.26               36786.44
#
#        avg_frequency_login_days  points_in_wallet used_special_discount  \
# 0                           7.0        733.830000                   Yes
# 1                           9.0        726.000000                   Yes
# 2                          21.0        713.780000                   Yes
# 3                          11.0        744.970000                   Yes
# 4                           8.0        299.048351                    No
# ...                         ...               ...                   ...
# 19914                      18.0        708.120000                    No
# 19915                     Error        574.340000                    No
# 19916                      24.0        564.300000                    No
# 19917                      22.0        606.340000                    No
# 19918                     Error       1193.689813                    No
#
#        offer_application_preference past_complaint          complaint_status  \
# 0                                No             No            Not Applicable
# 1                                No             No            Not Applicable
# 2                                No            Yes       Solved in Follow-up
# 3                                No            Yes  No Information Available
# 4                               Yes            Yes       Solved in Follow-up
# ...                             ...            ...                       ...
# 19914                           Yes             No            Not Applicable
# 19915                           Yes             No            Not Applicable
# 19916                           Yes            Yes                  Unsolved
# 19917                           Yes             No            Not Applicable
# 19918                           Yes            Yes                  Unsolved
#
#                    feedback
# 0      Poor Product Quality
# 1              Poor Website
# 2       No reason specified
# 3              Too many ads
# 4              Poor Website
# ...                     ...
# 19914  Poor Product Quality
# 19915   No reason specified
# 19916   No reason specified
# 19917          Poor Website
# 19918          Too many ads
#
# [19919 rows x 22 columns]

# %% [markdown]
# # Checking Null Values

# %%
#ratio of null values
train_df.isnull().sum()/test_df.shape[0]*100
# Out:
# customer_id                      0.000000
# age                              0.000000
# gender                           0.000000
# security_no                      0.000000
# region_category                 14.673443
# membership_category              0.000000
# joining_date                     0.000000
# joined_through_referral          0.000000
# preferred_offer_types            0.778547
# medium_of_operation              0.000000
# internet_option                  0.000000
# last_visit_time                  0.000000
# days_since_last_login            0.000000
# avg_time_spent                   0.000000
# avg_transaction_value            0.000000
# avg_frequency_login_days         0.000000
# points_in_wallet                 9.307418
# used_special_discount            0.000000
# offer_application_preference     0.000000
# past_complaint                   0.000000
# complaint_status                 0.000000
# feedback                         0.000000
# churn_risk_score                 0.000000
# dtype: float64

# %%
#ratio of null values
test_df.isnull().sum()/test_df.shape[0]*100
# Out:
# customer_id                      0.000000
# age                              0.000000
# gender                           0.000000
# security_no                      0.000000
# region_category                 14.799940
# membership_category              0.000000
# joining_date                     0.000000
# joined_through_referral          0.000000
# preferred_offer_types            0.798233
# medium_of_operation              0.000000
# internet_option                  0.000000
# last_visit_time                  0.000000
# days_since_last_login            0.000000
# avg_time_spent                   0.000000
# avg_transaction_value            0.000000
# avg_frequency_login_days         0.000000
# points_in_wallet                 9.854912
# used_special_discount            0.000000
# offer_application_preference     0.000000
# past_complaint                   0.000000
# complaint_status                 0.000000
# feedback                         0.000000
# dtype: float64

# %% [markdown]
# # Treating Null Values

# %%
train_df['region_category'] = train_df['region_category'].fillna(train_df['region_category'].mode()[0])
train_df['preferred_offer_types'] = train_df['preferred_offer_types'].fillna(train_df['preferred_offer_types'].mode()[0])
train_df['points_in_wallet'] = train_df['points_in_wallet'].fillna(train_df['points_in_wallet'].mean())


test_df['region_category'] = test_df['region_category'].fillna(test_df['region_category'].mode()[0])
test_df['preferred_offer_types'] = test_df['preferred_offer_types'].fillna(test_df['preferred_offer_types'].mode()[0])
test_df['points_in_wallet'] = test_df['points_in_wallet'].fillna(test_df['points_in_wallet'].mean())

# %%
#checking null values is present or not
print(train_df.info())
print('-'*50)
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36992 entries, 0 to 36991
# Data columns (total 23 columns):
# customer_id                     36992 non-null object
# age                             36992 non-null int64
# gender                          36992 non-null object
# security_no                     36992 non-null object
# region_category                 36992 non-null object
# membership_category             36992 non-null object
# joining_date                    36992 non-null object
# joined_through_referral         36992 non-null object
# preferred_offer_types           36992 non-null object
# medium_of_operation             36992 non-null object
# internet_option                 36992 non-null object
# last_visit_time                 36992 non-null object
# days_since_last_login           36992 non-null int64
# avg_time_spent                  36992 non-null float64
# avg_transaction_value           36992 non-null float64
# avg_frequency_login_days        36992 non-null object
# points_in_wallet                36992 non-null float64
# used_special_discount           36992 non-null object
# offer_application_preference    36992 non-null object
# past_complaint                  36992 non-null object
# complaint_status                36992 non-null object
# feedback                        36992 non-null object
# churn_risk_score                36992 non-null int64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 6.5+ MB
# None
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19919 entries, 0 to 19918
# Data columns (total 22 columns):
# customer_id                     19919 non-null object
# age                             19919 non-null int64
# gender                          19919 non-null object
# security_no                     19919 non-null object
# region_category                 19919 non-null object
# membership_category             19919 non-null object
# joining_date                    19919 non-null object
# joined_through_referral         19919 non-null object
# preferred_offer_types           19919 non-null object
# medium_of_operation             19919 non-null object
# internet_option                 19919 non-null object
# last_visit_time                 19919 non-null object
# days_since_last_login           19919 non-null int64
# avg_time_spent                  19919 non-null float64
# avg_transaction_value           19919 non-null float64
# avg_frequency_login_days        19919 non-null object
# points_in_wallet                19919 non-null float64
# used_special_discount           19919 non-null object
# offer_application_preference    19919 non-null object
# past_complaint                  19919 non-null object
# complaint_status                19919 non-null object
# feedback                        19919 non-null object
# dtypes: float64(3), int64(2), object(17)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# # DATA VISUALIZATION

# %%
sb.distplot(train_df.age)   #age is uniformly distributed

# %%
train_df["gender"].value_counts()
# Out:
# F          18490
# M          18443
# Unknown       59
# Name: gender, dtype: int64

# %%
train_df[train_df.gender == "Unknown"]
# Out:
#                                 customer_id  age   gender security_no  \
# 931    fffe43004900440031003500390037003700   13  Unknown     TF082U8
# 1083   fffe43004900440035003300310032003700   57  Unknown     D213GXR
# 1668   fffe43004900440034003200330033003300   40  Unknown     LUSZ08K
# 1843   fffe43004900440033003100360031003500   63  Unknown     FCFE5S7
# 2002   fffe43004900440032003100330031003100   26  Unknown     9HGPISM
# 2009   fffe43004900440034003200340032003000   12  Unknown     52J0SCU
# 2354   fffe43004900440035003200380031003700   17  Unknown     37X1PDZ
# 3012   fffe43004900440032003200370033003100   51  Unknown     1FZ9LXL
# 3278   fffe43004900440036003100330030003500   63  Unknown     6KGICZ5
# 5020   fffe43004900440032003000370038003500   18  Unknown     UKPDOET
# 5153   fffe43004900440034003900390034003800   53  Unknown     9FDSACX
# 5172   fffe43004900440034003000320039003300   40  Unknown     W55LPX3
# 6207   fffe43004900440031003100330034003300   54  Unknown     3B1I9U9
# 6233   fffe43004900440032003300350031003900   19  Unknown     3SSAQ5T
# 7299   fffe43004900440031003800300039003700   35  Unknown     4I2TUIN
# 7918           fffe430049004400370039003800   57  Unknown     EZKPUZX
# 8320   fffe43004900440034003500380030003700   21  Unknown     FH6DJ0S
# 8556   fffe43004900440036003300350030003700   31  Unknown     0NLBX2F
# 8831   fffe43004900440036003100330036003600   20  Unknown     I99GV8P
# 9310   fffe43004900440032003100300037003900   64  Unknown     U86AAFS
# 10416  fffe43004900440035003100340030003400   20  Unknown     6SL1V4O
# 10450      fffe4300490044003100340039003000   32  Unknown     OL25P3T
# 11106  fffe43004900440033003700320037003600   46  Unknown     Y6GHIJO
# 12885  fffe43004900440032003600330037003700   41  Unknown     F0MUFBC
# 13782      fffe4300490044003600380035003600   57  Unknown     12PPUEV
# 14626  fffe43004900440033003000340031003800   28  Unknown     N9WH3XH
# 16510  fffe43004900440034003400340035003100   54  Unknown     VGTI6LO
# 17654      fffe4300490044003100360036003700   21  Unknown     EXIXUYN
# 19074  fffe43004900440032003800360034003700   53  Unknown     L7DABDL
# 20510  fffe43004900440035003600350032003400   23  Unknown     LQ3RO8A
# 20557  fffe43004900440036003100360035003900   47  Unknown     0CY3YP9
# 22141      fffe4300490044003100380030003800   34  Unknown     25IGC23
# 22232  fffe43004900440033003800330037003800   52  Unknown     5TE5ZQH
# 22453  fffe43004900440032003500370038003700   63  Unknown     9S3OJ1Y
# 22761  fffe43004900440033003000300031003300   20  Unknown     UZD7HPU
# 22847      fffe4300490044003100310030003600   13  Unknown     Z0GHVFX
# 23303  fffe43004900440032003100350030003800   43  Unknown     YSMXD14
# 23828  fffe43004900440035003000310031003000   34  Unknown     H46DONW
# 23928  fffe43004900440034003200320039003300   53  Unknown     FSWCSH3
# 24145  fffe43004900440035003400380032003500   24  Unknown     2BPOLFH
# 25146      fffe4300490044003500380031003300   25  Unknown     ND1AZAL
# 25509  fffe43004900440035003300390036003200   51  Unknown     8P11W5E
# 25566  fffe43004900440035003500340037003500   54  Unknown     JT03KJI
# 27290      fffe4300490044003200380037003500   11  Unknown     O08ICJR
# 27463      fffe4300490044003800330035003800   50  Unknown     9LWEF1H
# 27890  fffe43004900440036003100390034003400   39  Unknown     9WVQ06F
# 27950  fffe43004900440033003000340036003500   38  Unknown     GFK4LRF
# 28408  fffe43004900440032003400380036003300   36  Unknown     1GSNYVV
# 29937  fffe43004900440032003600340039003600   33  Unknown     AKDCP72
# 30058      fffe4300490044003100300036003300   35  Unknown     XB74GKH
# 30500  fffe43004900440031003100350033003900   64  Unknown     JYW8ODZ
# 30624      fffe4300490044003700360037003100   11  Unknown     RFY1JZU
# 30868  fffe43004900440032003800300037003300   59  Unknown     TB3S0BI
# 31831  fffe43004900440034003300340031003400   15  Unknown     GFP1TAT
# 34183  fffe43004900440031003500320038003300   38  Unknown     1RXLS7F
# 35229      fffe4300490044003800350031003400   44  Unknown     JZNY1RG
# 35555  fffe43004900440034003600320037003000   50  Unknown     XXOLWUP
# 35824      fffe4300490044003900390034003900   37  Unknown     YPPANQP
# 35887  fffe43004900440036003300330036003200   40  Unknown     KTQJPW4
#
#       region_category  membership_category joining_date  \
# 931              Town        No Membership   2016-06-22
# 1083             Town   Premium Membership   2015-07-13
# 1668             City   Premium Membership   2016-02-20
# 1843             Town     Basic Membership   2016-09-01
# 2002             City     Basic Membership   2017-05-07
# 2009             City  Platinum Membership   2016-10-02
# 2354             Town  Platinum Membership   2016-01-19
# 3012          Village      Gold Membership   2016-03-23
# 3278             City        No Membership   2016-01-31
# 5020             Town  Platinum Membership   2015-12-15
# 5153             Town        No Membership   2016-07-06
# 5172             City    Silver Membership   2017-01-01
# 6207             Town        No Membership   2015-02-08
# 6233             Town     Basic Membership   2017-10-12
# 7299             City     Basic Membership   2016-03-08
# 7918          Village    Silver Membership   2017-09-07
# 8320             Town     Basic Membership   2016-12-10
# 8556             Town     Basic Membership   2016-10-01
# 8831             Town   Premium Membership   2016-12-20
# 9310             City     Basic Membership   2017-02-25
# 10416            Town   Premium Membership   2017-04-06
# 10450            City    Silver Membership   2016-01-30
# 11106            Town    Silver Membership   2017-08-30
# 12885            City        No Membership   2016-11-05
# 13782            City        No Membership   2017-05-20
# 14626            Town    Silver Membership   2017-12-12
# 16510            Town        No Membership   2017-07-11
# 17654            Town      Gold Membership   2015-03-05
# 19074         Village     Basic Membership   2015-09-13
# 20510         Village   Premium Membership   2017-10-28
# 20557            Town    Silver Membership   2015-04-20
# 22141         Village   Premium Membership   2015-05-20
# 22232            Town      Gold Membership   2017-08-03
# 22453            City   Premium Membership   2015-06-15
# 22761            City        No Membership   2016-07-23
# 22847            Town        No Membership   2016-09-18
# 23303            Town    Silver Membership   2016-11-16
# 23828            City      Gold Membership   2015-04-15
# 23928            Town   Premium Membership   2015-05-02
# 24145            Town    Silver Membership   2015-01-06
# 25146            Town    Silver Membership   2016-09-05
# 25509            Town      Gold Membership   2016-01-07
# 25566            City     Basic Membership   2017-03-18
# 27290            Town     Basic Membership   2015-01-16
# 27463            Town     Basic Membership   2015-12-31
# 27890            City     Basic Membership   2017-03-06
# 27950         Village      Gold Membership   2015-09-07
# 28408            Town   Premium Membership   2016-12-23
# 29937            Town   Premium Membership   2017-10-23
# 30058            Town      Gold Membership   2015-07-08
# 30500            City     Basic Membership   2017-04-27
# 30624            Town        No Membership   2017-04-20
# 30868            Town      Gold Membership   2015-01-29
# 31831            Town      Gold Membership   2016-08-28
# 34183            Town     Basic Membership   2015-04-19
# 35229            Town  Platinum Membership   2016-09-04
# 35555            Town   Premium Membership   2015-11-23
# 35824            Town      Gold Membership   2015-12-27
# 35887            Town        No Membership   2017-08-28
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 931                        No  Credit/Debit Card Offers          Smartphone
# 1083                      Yes     Gift Vouchers/Coupons          Smartphone
# 1668                       No     Gift Vouchers/Coupons             Desktop
# 1843                      Yes  Credit/Debit Card Offers             Desktop
# 2002                        ?            Without Offers          Smartphone
# 2009                       No     Gift Vouchers/Coupons             Desktop
# 2354                       No     Gift Vouchers/Coupons                Both
# 3012                       No     Gift Vouchers/Coupons             Desktop
# 3278                       No  Credit/Debit Card Offers             Desktop
# 5020                       No  Credit/Debit Card Offers          Smartphone
# 5153                       No     Gift Vouchers/Coupons                Both
# 5172                       No            Without Offers             Desktop
# 6207                      Yes            Without Offers                   ?
# 6233                      Yes            Without Offers          Smartphone
# 7299                      Yes  Credit/Debit Card Offers                   ?
# 7918                       No            Without Offers                   ?
# 8320                       No  Credit/Debit Card Offers                   ?
# 8556                      Yes  Credit/Debit Card Offers          Smartphone
# 8831                       No     Gift Vouchers/Coupons          Smartphone
# 9310                        ?            Without Offers             Desktop
# 10416                     Yes  Credit/Debit Card Offers          Smartphone
# 10450                      No  Credit/Debit Card Offers          Smartphone
# 11106                     Yes            Without Offers             Desktop
# 12885                     Yes            Without Offers                   ?
# 13782                     Yes     Gift Vouchers/Coupons          Smartphone
# 14626                      No     Gift Vouchers/Coupons          Smartphone
# 16510                     Yes  Credit/Debit Card Offers                Both
# 17654                      No     Gift Vouchers/Coupons                Both
# 19074                     Yes     Gift Vouchers/Coupons                   ?
# 20510                     Yes     Gift Vouchers/Coupons                   ?
# 20557                     Yes     Gift Vouchers/Coupons             Desktop
# 22141                      No     Gift Vouchers/Coupons             Desktop
# 22232                     Yes     Gift Vouchers/Coupons                   ?
# 22453                       ?     Gift Vouchers/Coupons          Smartphone
# 22761                     Yes            Without Offers          Smartphone
# 22847                       ?  Credit/Debit Card Offers          Smartphone
# 23303                      No     Gift Vouchers/Coupons                   ?
# 23828                     Yes  Credit/Debit Card Offers             Desktop
# 23928                      No     Gift Vouchers/Coupons             Desktop
# 24145                     Yes  Credit/Debit Card Offers          Smartphone
# 25146                      No  Credit/Debit Card Offers          Smartphone
# 25509                      No  Credit/Debit Card Offers             Desktop
# 25566                      No     Gift Vouchers/Coupons          Smartphone
# 27290                     Yes            Without Offers             Desktop
# 27463                     Yes     Gift Vouchers/Coupons                   ?
# 27890                       ?     Gift Vouchers/Coupons                   ?
# 27950                      No  Credit/Debit Card Offers          Smartphone
# 28408                     Yes     Gift Vouchers/Coupons          Smartphone
# 29937                     Yes     Gift Vouchers/Coupons             Desktop
# 30058                     Yes     Gift Vouchers/Coupons             Desktop
# 30500                       ?  Credit/Debit Card Offers             Desktop
# 30624                     Yes            Without Offers             Desktop
# 30868                       ?     Gift Vouchers/Coupons             Desktop
# 31831                     Yes            Without Offers                   ?
# 34183                       ?     Gift Vouchers/Coupons                   ?
# 35229                     Yes     Gift Vouchers/Coupons          Smartphone
# 35555                       ?            Without Offers          Smartphone
# 35824                      No     Gift Vouchers/Coupons                   ?
# 35887                       ?  Credit/Debit Card Offers             Desktop
#
#        ... avg_time_spent avg_transaction_value  avg_frequency_login_days  \
# 931    ...      84.850000              24412.90                      29.0
# 1083   ...     353.370000              42194.47                      14.0
# 1668   ...     121.160000              88003.76                       3.0
# 1843   ...     132.390000              34125.13                      28.0
# 2002   ...     259.820000              21380.00                     Error
# 2009   ...    -743.662389              53502.22                      14.0
# 2354   ...     345.630000              47045.76                      28.0
# 3012   ...      39.720000               9715.89                      16.0
# 3278   ...     185.570000              11549.49                      19.0
# 5020   ...     221.570000              12808.70                       7.0
# 5153   ...     298.540000              26023.86                       5.0
# 5172   ...     333.250000              21440.09                      18.0
# 6207   ...     553.050000              44591.74                      11.0
# 6233   ...    -856.489396               3705.98                       6.0
# 7299   ...    1117.625030              27891.86        -10.49192090165749
# 7918   ...      40.770000              45277.75                      24.0
# 8320   ...      64.180000              44537.88                      26.0
# 8556   ...     166.680000              46906.09                      20.0
# 8831   ...      51.440000              19890.02                      27.0
# 9310   ...     191.160000               5494.05        1.3329749678872886
# 10416  ...     585.700000              65860.46                      15.0
# 10450  ...      33.610000               3459.41                      23.0
# 11106  ...      64.990000               3223.32                     Error
# 12885  ...      52.110000              28298.29                       6.0
# 13782  ...     122.520000              24127.76                      25.0
# 14626  ...     134.610000               9621.78                      28.0
# 16510  ...     387.580000              23137.31                      22.0
# 17654  ...     314.290000              42597.72                      16.0
# 19074  ...     650.070000              26235.35       -0.5099253452416121
# 20510  ...      93.880000              38875.53                      22.0
# 20557  ...     262.650000              35934.73                      19.0
# 22141  ...     268.680000              71118.70                       1.0
# 22232  ...     128.280000              15277.33                      28.0
# 22453  ...     207.220000              42979.13                      10.0
# 22761  ...     278.650000              14467.98                      20.0
# 22847  ...     549.900000              15737.81                       9.0
# 23303  ...     364.520000              42855.29                     Error
# 23828  ...      31.100000               3355.64                       8.0
# 23928  ...     142.510000              69084.83                     Error
# 24145  ...     197.940000              21549.33                      26.0
# 25146  ...     137.740000               8956.26                      25.0
# 25509  ...     164.880000              13585.93                      12.0
# 25566  ...     156.070000              32463.61                      16.0
# 27290  ...      92.950000              33376.51                      23.0
# 27463  ...     450.400000              24778.46                      19.0
# 27890  ...     789.990000               2394.36                      23.0
# 27950  ...      34.970000              41641.74                      17.0
# 28408  ...      33.130000              35942.83                      16.0
# 29937  ...     537.820000               2585.85                      21.0
# 30058  ...      40.150000               8876.53                      13.0
# 30500  ...     562.190000              47935.09       -12.806326974941197
# 30624  ...      57.540000               7710.83                       7.0
# 30868  ...   -1056.695076              16792.90                       9.0
# 31831  ...      32.700000              37922.81                      14.0
# 34183  ...     266.570000              10281.69                      19.0
# 35229  ...      66.480000              32171.47                      26.0
# 35555  ...      68.900000              30754.59                      13.0
# 35824  ...    -942.199988              38403.58                      19.0
# 35887  ...      47.820000              41701.33                      14.0
#
#        points_in_wallet  used_special_discount offer_application_preference  \
# 931          657.150000                     No                          Yes
# 1083         705.040000                    Yes                          Yes
# 1668         838.580000                     No                          Yes
# 1843         567.160000                     No                          Yes
# 2002         686.882199                     No                          Yes
# 2009         798.420000                    Yes                          Yes
# 2354         391.889304                    Yes                           No
# 3012         783.140000                     No                          Yes
# 3278         709.200000                     No                          Yes
# 5020         686.882199                    Yes                           No
# 5153         672.710000                     No                          Yes
# 5172         749.310000                    Yes                           No
# 6207         652.990000                    Yes                           No
# 6233         544.900000                     No                          Yes
# 7299         592.810000                    Yes                           No
# 7918         725.730000                     No                          Yes
# 8320         716.140000                     No                          Yes
# 8556         661.810000                    Yes                           No
# 8831         712.140000                     No                          Yes
# 9310         505.030000                    Yes                           No
# 10416        686.882199                    Yes                          Yes
# 10450        650.910000                     No                          Yes
# 11106        354.905291                    Yes                           No
# 12885        548.630000                     No                          Yes
# 13782        686.882199                    Yes                           No
# 14626        686.882199                     No                          Yes
# 16510        621.850000                    Yes                           No
# 17654        722.580000                    Yes                           No
# 19074        532.600000                     No                          Yes
# 20510       1181.889841                    Yes                           No
# 20557        784.300000                    Yes                          Yes
# 22141        686.882199                    Yes                           No
# 22232        787.840000                    Yes                           No
# 22453        787.440000                    Yes                          Yes
# 22761        686.882199                    Yes                           No
# 22847        573.000000                     No                          Yes
# 23303        742.620000                     No                          Yes
# 23828        693.080000                     No                          Yes
# 23928        311.797739                     No                          Yes
# 24145        794.720000                    Yes                           No
# 25146        681.800000                    Yes                           No
# 25509       1103.798445                    Yes                           No
# 25566        639.820000                    Yes                           No
# 27290        656.130000                    Yes                           No
# 27463        682.430000                    Yes                           No
# 27890        597.290000                    Yes                          Yes
# 27950        770.720000                     No                          Yes
# 28408        755.970000                     No                          Yes
# 29937       1092.297002                     No                          Yes
# 30058        703.140000                     No                          Yes
# 30500        653.810000                     No                          Yes
# 30624        686.882199                     No                          Yes
# 30868        658.160000                     No                          Yes
# 31831        731.120000                    Yes                           No
# 34183        675.330000                    Yes                           No
# 35229        700.080000                    Yes                           No
# 35555        785.120000                     No                          Yes
# 35824        686.882199                     No                          Yes
# 35887        704.730000                     No                          Yes
#
#        past_complaint          complaint_status                  feedback  \
# 931                No            Not Applicable      Poor Product Quality
# 1083               No            Not Applicable              Too many ads
# 1668              Yes  No Information Available  Products always in Stock
# 1843              Yes                  Unsolved              Too many ads
# 2002               No            Not Applicable              Poor Website
# 2009              Yes  No Information Available  Products always in Stock
# 2354              Yes                  Unsolved      Poor Product Quality
# 3012               No            Not Applicable      Poor Product Quality
# 3278              Yes       Solved in Follow-up              Poor Website
# 5020              Yes       Solved in Follow-up       No reason specified
# 5153               No            Not Applicable     Poor Customer Service
# 5172               No            Not Applicable  Products always in Stock
# 6207               No            Not Applicable     Poor Customer Service
# 6233              Yes       Solved in Follow-up              Poor Website
# 7299               No            Not Applicable              Too many ads
# 7918               No            Not Applicable       No reason specified
# 8320              Yes  No Information Available     Poor Customer Service
# 8556               No            Not Applicable              Too many ads
# 8831               No            Not Applicable     Poor Customer Service
# 9310              Yes       Solved in Follow-up      Poor Product Quality
# 10416              No            Not Applicable     Quality Customer Care
# 10450             Yes       Solved in Follow-up              Poor Website
# 11106              No            Not Applicable              Poor Website
# 12885             Yes                  Unsolved      Poor Product Quality
# 13782              No            Not Applicable      Poor Product Quality
# 14626              No            Not Applicable       No reason specified
# 16510              No            Not Applicable      Poor Product Quality
# 17654              No            Not Applicable     Poor Customer Service
# 19074             Yes  No Information Available       No reason specified
# 20510             Yes                  Unsolved              Poor Website
# 20557             Yes                    Solved              Poor Website
# 22141             Yes                    Solved     Quality Customer Care
# 22232             Yes                    Solved     Poor Customer Service
# 22453              No            Not Applicable      Poor Product Quality
# 22761              No            Not Applicable     Poor Customer Service
# 22847             Yes                  Unsolved              Too many ads
# 23303              No            Not Applicable       No reason specified
# 23828              No            Not Applicable     Poor Customer Service
# 23928             Yes                  Unsolved     Quality Customer Care
# 24145             Yes                    Solved              Too many ads
# 25146             Yes                  Unsolved     Poor Customer Service
# 25509             Yes       Solved in Follow-up     Poor Customer Service
# 25566             Yes  No Information Available      Poor Product Quality
# 27290              No            Not Applicable              Too many ads
# 27463             Yes                    Solved     Poor Customer Service
# 27890              No            Not Applicable       No reason specified
# 27950              No            Not Applicable     User Friendly Website
# 28408              No            Not Applicable      Poor Product Quality
# 29937             Yes  No Information Available     Poor Customer Service
# 30058              No            Not Applicable     Poor Customer Service
# 30500             Yes                    Solved      Poor Product Quality
# 30624              No            Not Applicable       No reason specified
# 30868             Yes                  Unsolved              Poor Website
# 31831             Yes                  Unsolved       No reason specified
# 34183              No            Not Applicable              Poor Website
# 35229             Yes                    Solved              Too many ads
# 35555             Yes                  Unsolved              Poor Website
# 35824              No            Not Applicable     Poor Customer Service
# 35887             Yes                    Solved              Too many ads
#
#       churn_risk_score
# 931                  5
# 1083                 3
# 1668                 1
# 1843                 5
# 2002                 5
# 2009                 2
# 2354                 3
# 3012                 3
# 3278                 4
# 5020                 3
# 5153                 4
# 5172                 2
# 6207                 5
# 6233                 5
# 7299                 5
# 7918                 3
# 8320                 4
# 8556                 5
# 8831                 3
# 9310                 5
# 10416                1
# 10450                4
# 11106                4
# 12885                5
# 13782                5
# 14626                3
# 16510                5
# 17654                3
# 19074                5
# 20510                3
# 20557                3
# 22141                1
# 22232                3
# 22453                3
# 22761                5
# 22847                5
# 23303               -1
# 23828                4
# 23928                2
# 24145                3
# 25146                4
# 25509                3
# 25566                4
# 27290                5
# 27463                5
# 27890                5
# 27950                1
# 28408                3
# 29937                3
# 30058               -1
# 30500                4
# 30624                5
# 30868               -1
# 31831                3
# 34183                5
# 35229                3
# 35555                3
# 35824                3
# 35887                4
#
# [59 rows x 23 columns]

# %%
train_df.drop(train_df.index[train_df['gender'] == 'Unknown'],axis = 0,  inplace = True)

# %%
sb.countplot(train_df.gender) #male and female is equaly distributed

# %%
# checking the distribution of outcomes
sb.countplot(x = 'churn_risk_score', data = train_df)

# %%
sb.countplot(train_df.gender,hue=train_df.churn_risk_score)

# %%
cat = []
con = []
for i in train_df.columns:
    if (train_df[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
for i in cat:
    test_df[i]=label_encoder.fit_transform(test_df[i])

# %%
for i in cat:
    train_df[i]=label_encoder.fit_transform(train_df[i])

# %%
convert = ["avg_time_spent","avg_transaction_value","points_in_wallet"]
for k in convert:
    train_df[k] = train_df[k].astype(int)

# %%
for k in convert:
    test_df[k] = test_df[k].astype(int)

# %% [markdown]
# ### Checking Variance

# %%
train_df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'security_no', 'region_category',
#        'membership_category', 'joining_date', 'joined_through_referral',
#        'preferred_offer_types', 'medium_of_operation', 'internet_option',
#        'last_visit_time', 'days_since_last_login', 'avg_time_spent',
#        'avg_transaction_value', 'avg_frequency_login_days', 'points_in_wallet',
#        'used_special_discount', 'offer_application_preference',
#        'past_complaint', 'complaint_status', 'feedback', 'churn_risk_score'],
#       dtype='object')

# %%
# checking variance
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = train_df[['customer_id', 'age', 'gender', 'security_no', 'region_category',
       'membership_category', 'joining_date', 'joined_through_referral',
       'preferred_offer_types', 'medium_of_operation', 'internet_option',
       'last_visit_time', 'days_since_last_login', 'avg_time_spent',
       'avg_transaction_value', 'avg_frequency_login_days', 'points_in_wallet',
       'used_special_discount', 'offer_application_preference',
       'past_complaint', 'complaint_status', 'feedback', 'churn_risk_score']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif['Features'] = variables.columns

# %%
vif
# Out:
#           VIF                      Features
# 0    3.924364                   customer_id
# 1    6.075019                           age
# 2    1.978020                        gender
# 3    3.874535                   security_no
# 4    2.407517               region_category
# 5    2.938436           membership_category
# 6    3.875618                  joining_date
# 7    4.200611       joined_through_referral
# 8    2.468713         preferred_offer_types
# 9    4.515936           medium_of_operation
# 10   2.476405               internet_option
# 11   3.874789               last_visit_time
# 12   1.033813         days_since_last_login
# 13   1.476250                avg_time_spent
# 14   3.502689         avg_transaction_value
# 15   6.775358      avg_frequency_login_days
# 16  12.749015              points_in_wallet
# 17   5.998962         used_special_discount
# 18   6.021391  offer_application_preference
# 19   2.712507                past_complaint
# 20   3.765156              complaint_status
# 21   2.623929                      feedback
# 22   7.221041              churn_risk_score

# %%
train = train_df.drop(['points_in_wallet'],axis = 1)
test = test_df.drop(['points_in_wallet'],axis = 1)

# %% [markdown]
# # model building

# %%
X= train.drop(columns = ['churn_risk_score'], axis=1)
y= train[['churn_risk_score']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %% [markdown]
# #### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %% [markdown]
# #### Making Predictions

# %%
pred = clf.predict(X_test)

# %% [markdown]
# #### Checking Accuracy

# %%
score = clf.score(X_test, y_test)
score
# Out:
# 0.5712738594828753

# %%
from sklearn import tree
s = plt.figure(figsize=(20,10))
tree.plot_tree(clf, max_depth=2, filled=True, fontsize=10)
plt.title("Decision Tree for Customer Churn Data", fontsize=30)
plt.show()

# %% [markdown]
# #### Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf = rf.fit(X_train,y_train)

# %% [markdown]
# #### Prediction

# %%
pred1 = rf.predict(X_test)

# %% [markdown]
# #### Checking Accuracy

# %%
score1 = rf.score(X_test, y_test)
score1
# Out:
# 0.5911736834980371

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb = gb.fit(X_train,y_train)

# %% [markdown]
# #### Prediction

# %%
pred2 = gb.predict(X_test)

# %% [markdown]
# #### Checking Accuracy

# %%
score2 = gb.score(X_test, y_test)
score2
# Out:
# 0.6363882496277243

# %% [markdown]
# #### AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ad = AdaBoostClassifier()
ad = ad.fit(X_train,y_train)

# %% [markdown]
# #### Prediction

# %%
pred3 = ad.predict(X_test)

# %% [markdown]
# #### Checking Accuracy

# %%
score3 = ad.score(X_test, y_test)
score3
# Out:
# 0.44794909976986597

# %% [markdown]
# GRADIENT BOOSTING IS THE PREDICTOR AMONG THOSE MODELS
