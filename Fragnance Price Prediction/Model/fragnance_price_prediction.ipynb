# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# **LOADING THE DATASET**

# %%
data=pd.read_csv("Pricelist -All Fragrances (1).csv")

# %%
data
# Out:
#       ItemNumber         Name                             Size/Type Gender  \
# 0         512069  007 Quantum           75 ml Eau De Toilette Spray    Men
# 1         548436  007 Quantum  75 ml Eau De Toilette Spray (Tester)    Men
# 2         460836    1 Million           50 ml Eau De Toilette Spray    Men
# 3         490517    1 Million                 75 ml Deodorant Stick    Men
# 4         490516    1 Million                    100 ml After Shave    Men
# ...          ...          ...                                   ...    ...
# 9569      403066         Zirh           75 ml Eau De Toilette Spray    Men
# 9570      462146    Zirh Ikon          125 ml Eau De Toilette Spray    Men
# 9571      492054    Zirh Ikon           75 ml Eau De Toilette Spray    Men
# 9572      551477       Ziryab   117 ml Eau De Parfum Spray (Unisex)  Women
# 9573      498951    Zoa Night            100 ml Eau De Parfum Spray  Women
#
#      Retail Price (in INR) Cost (in INR)
# ...

# %%
data.head()
# Out:
#    ItemNumber         Name                             Size/Type Gender  \
# 0      512069  007 Quantum           75 ml Eau De Toilette Spray    Men
# 1      548436  007 Quantum  75 ml Eau De Toilette Spray (Tester)    Men
# 2      460836    1 Million           50 ml Eau De Toilette Spray    Men
# 3      490517    1 Million                 75 ml Deodorant Stick    Men
# 4      490516    1 Million                    100 ml After Shave    Men
#
#   Retail Price (in INR) Cost (in INR)
# 0                   NaN      1,834.03
# 1                   NaN        815.78
# 2              5,932.96      3,193.42
# 3                   NaN      1,668.65
# 4                   NaN      3,114.06

# %%
data.tail()
# Out:
#       ItemNumber       Name                            Size/Type Gender  \
# 9569      403066       Zirh          75 ml Eau De Toilette Spray    Men
# 9570      462146  Zirh Ikon         125 ml Eau De Toilette Spray    Men
# 9571      492054  Zirh Ikon          75 ml Eau De Toilette Spray    Men
# 9572      551477     Ziryab  117 ml Eau De Parfum Spray (Unisex)  Women
# 9573      498951  Zoa Night           100 ml Eau De Parfum Spray  Women
#
#      Retail Price (in INR) Cost (in INR)
# 9569              3,151.89        593.30
# 9570              4,820.53        852.86
# 9571                   NaN        517.65
# 9572                   NaN     12,236.73
# 9573                   NaN        852.86

# %%
data.describe()
# Out:
#           ItemNumber
# count    9574.000000
# mean   509195.716315
# std     50177.142884
# min    400007.000000
# 25%    466236.500000
# 50%    536039.500000
# 75%    547548.500000
# max    557489.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9574 entries, 0 to 9573
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ItemNumber             9574 non-null   int64
#  1   Name                   9574 non-null   object
#  2   Size/Type              9574 non-null   object
#  3   Gender                 9574 non-null   object
#  4   Retail Price (in INR)  2978 non-null   object
#  5   Cost (in INR)          9574 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 448.9+ KB

# %%
data.shape   #9574 rows and 6 columns in our dataset
# Out:
# (9574, 6)

# %%
data.value_counts()
# Out:
# ItemNumber  Name                     Size/Type                              Gender  Retail Price (in INR)  Cost (in INR)
# 400016      Obsession                30 ml Eau De Toilette Spray            Men     2,373.18               919.61           1
# 462266      Black Knight Classic     100 ml Eau De Parfum Spray             Men     4,598.04               1,287.45         1
# 462043      Encre Noire              100 ml Eau De Toilette Spray (Tester)  Men     7,045.39               1,557.40         1
# 462061      Ultrared                 100 ml Eau De Toilette Spray           Men     4,820.53               3,633.94         1
# 462109      Madagascar 2             75 ml Eau De Toilette Spray            Women   1,854.05               444.97           1
#                                                                                                                            ..
# ...

# %%
data.columns
# Out:
# Index(['ItemNumber', 'Name', 'Size/Type', 'Gender', 'Retail Price (in INR)',
#        'Cost (in INR)'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ItemNumber                int64
# Name                     object
# Size/Type                object
# Gender                   object
# Retail Price (in INR)    object
# Cost (in INR)            object
# dtype: object

# %%
data.mean()
# Out:
# ItemNumber    509195.716315
# dtype: float64

# %%
data.var()
# Out:
# ItemNumber    2.517746e+09
# dtype: float64

# %% [markdown]
# **Checking Null Values**

# %%
data.isnull().sum()
# Out:
# ItemNumber                  0
# Name                        0
# Size/Type                   0
# Gender                      0
# Retail Price (in INR)    6596
# Cost (in INR)               0
# dtype: int64

# %%
data.isnull().any()
# Out:
# ItemNumber               False
# Name                     False
# Size/Type                False
# Gender                   False
# Retail Price (in INR)     True
# Cost (in INR)            False
# dtype: bool

# %%
data.isnull().all()
# Out:
# ItemNumber               False
# Name                     False
# Size/Type                False
# Gender                   False
# Retail Price (in INR)    False
# Cost (in INR)            False
# dtype: bool

# %% [markdown]
# ![](https://3.imimg.com/data3/LV/US/MDC-6722648/images-fine-img-500x500.jpg)

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **HISTOGRAM**
#
# **A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis gives information about frequency.**

# %%
data.hist(figsize=(20,14))
plt.show()

# %% [markdown]
# **SCATTER PLOT**
#
# **A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.**

# %%
sns.scatterplot(x='Name',y='Cost (in INR)',data=data)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Cost (in INR)'>

# %% [markdown]
# **KDE PLOT (DENSITY PLOT)**
#
# **KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.**

# %%
sns.kdeplot(x='Name',y='Cost (in INR)',data=data)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Cost (in INR)'>

# %% [markdown]
# **JOINTPLOT**
#
# **Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins. This plot is a convenience class that wraps JointGrid.**

# %%
sns.jointplot(x='Name',y='Cost (in INR)',data=data)

# %% [markdown]
# **Count plot**
#
# **A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable. The basic API and options are identical to those for barplot() , so you can compare counts across nested variables.**

# %%
plt.figure(figsize=(6,6))

x= data.Gender.value_counts()
sns.countplot(x= "Gender",data= data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# **RELPLOT**
#
# **This is a figure-level function for visualizing statistical relationships using two common approaches: scatter plots and line plots. ... relplot() combines a FacetGrid with one of two axes-level functions: scatterplot() (with kind="scatter" ; the default)**

# %%
sns.relplot(x='Size/Type',y='Cost (in INR)',data=data)

# %% [markdown]
# ![](https://www.recablog.com/wp-content/uploads/2021/01/fragnances-scaled.jpg)

# %% [markdown]
# # Data Pre Processing

# %%
data.corr()
# Out:
#                        ItemNumber      Name  Size/Type    Gender  \
# ItemNumber               1.000000  0.041283  -0.027552  0.056940
# Name                     0.041283  1.000000  -0.000121  0.010629
# Size/Type               -0.027552 -0.000121   1.000000  0.048938
# Gender                   0.056940  0.010629   0.048938  1.000000
# Retail Price (in INR)    0.682291  0.046768  -0.013831  0.028666
# Cost (in INR)            0.054755  0.055578  -0.039135  0.046714
#
#                        Retail Price (in INR)  Cost (in INR)
# ItemNumber                          0.682291       0.054755
# Name                                0.046768       0.055578
# Size/Type                          -0.013831      -0.039135
# Gender                              0.028666       0.046714
# Retail Price (in INR)               1.000000      -0.008856
# Cost (in INR)                      -0.008856       1.000000

# %% [markdown]
# **HeatMap**
#
# **A heatmap is a graphical representation of data that uses a system of color-coding to represent different values. Heatmaps are used in various forms of analytics but are most commonly used to show user behaviour on specific webpages or webpage templates.**

# %%
plt.figure(figsize = (12,10))

sns.heatmap(data.corr(), annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **BarPlot**
#
# **A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.**

# %%
plt.style.use("default")
sns.barplot(x="Gender", y="ItemNumber", data=data[170:180])
plt.title("Gender vs ItemNumber",fontsize=15)
plt.xlabel("Gender")
plt.ylabel("ItemNumber")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Gender", y="Name", data=data[170:180])
plt.title("Gender vs Name",fontsize=15)
plt.xlabel("Gender")
plt.ylabel("Name")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Size/Type", y="Cost (in INR)", data=data[170:180])
plt.title("Size/Type vs Cost (in INR)",fontsize=15)
plt.xlabel("Size/Type")
plt.ylabel("Cost (in INR)")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Retail Price (in INR)", y="Cost (in INR)", data=data[170:180])
plt.title("Retail Price (in INR) vs Cost (in INR)",fontsize=15)
plt.xlabel("Retail Price (in INR)")
plt.ylabel("Cost (in INR)")
plt.show()

# %%
plt.style.use("default")
sns.barplot(x="Size/Type", y="Retail Price (in INR)", data=data[170:180])
plt.title("Size/Type vs Retail Price (in INR)",fontsize=15)
plt.xlabel("Size/Type")
plt.ylabel("Retail Price (in INR)")
plt.show()

# %% [markdown]
# **Boxplot**
#
# **A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). ... It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.**

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='Gender',data=data)
plt.subplot(2,3,2)
sns.boxplot(x='Name',data=data)
plt.subplot(2,3,3)
sns.boxplot(x='Size/Type',data=data)
plt.subplot(2,3,4)
sns.boxplot(x='ItemNumber',data=data)
plt.subplot(2,3,5)
sns.boxplot(x='Retail Price (in INR)',data=data)
plt.subplot(2,3,6)
sns.boxplot(x='Cost (in INR)',data=data)
# Out:
# <AxesSubplot:xlabel='Cost (in INR)'>

# %%
data.columns
# Out:
# Index(['ItemNumber', 'Name', 'Size/Type', 'Gender', 'Retail Price (in INR)',
#        'Cost (in INR)'],
#       dtype='object')

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       ItemNumber  Name  Size/Type  Gender  Retail Price (in INR)  \
# 0         512069     0       1102       0                    260
# 1         548436     0       1104       0                    260
# 2         460836     1        904       0                    189
# 3         490517     1       1080       0                    260
# 4         490516     1         51       0                    260
# ...          ...   ...        ...     ...                    ...
# 9569      403066  5751       1102       0                    119
# 9570      462146  5752        397       0                    163
# 9571      492054  5752       1102       0                    260
# 9572      551477  5753        321       1                    260
# 9573      498951  5754        117       1                    260
#
#       Cost (in INR)
# 0               170
# 1               956
# 2               511
# 3               146
# 4               497
# ...             ...
# 9569            825
# ...

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# ItemNumber               0
# Name                     0
# Size/Type                0
# Gender                   0
# Retail Price (in INR)    0
# Cost (in INR)            0
# dtype: int64

# %%
x = data.drop(columns = 'Gender')

# Getting Predicting Value
y = data['Gender']

# %% [markdown]
# # Training and Testing Data

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(len(x_train))
# Out:
# 7659

# %% [markdown]
# # Model Building

# %% [markdown]
# # 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.metrics import classification_report
y_pred_reg=reg.predict(x_test)
acc_reg = accuracy_score(y_test, y_pred_reg)
print("Classification Report is:\n",classification_report(y_test,y_pred_reg))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred_reg))
print("Training Score:\n",reg.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print(f"Accuracy Score of Logistic Regression is : {acc_reg}")
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       719
#            1       0.62      1.00      0.77      1196
#
#     accuracy                           0.62      1915
#    macro avg       0.31      0.50      0.38      1915
# weighted avg       0.39      0.62      0.48      1915
#
# Confusion Matrix:
#  [[   0  719]
#  [   0 1196]]
# Training Score:
#  63.82034208121164
# Mean Squared Error:
#  0.39530026109660577
# R2 score is:
#  -0.6857943260102053
# Accuracy Score of Logistic Regression is : 0.6245430809399478

# %% [markdown]
# # 2. KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.46      0.35      0.40       719
#            1       0.66      0.76      0.71      1196
#
#     accuracy                           0.60      1915
#    macro avg       0.56      0.55      0.55      1915
# weighted avg       0.59      0.60      0.59      1915
#
# Confusion Matrix:
#  [[252 467]
#  [290 906]]
# Training Score:
#  72.56822039430735
# Mean Squared Error:
#  0.39530026109660577
# R2 score is:
#  -0.6857943260102053
# Accuracy Score:
#  60.469973890339425

# %% [markdown]
# # 3. SVC

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       719
#            1       0.62      1.00      0.77      1196
#
#     accuracy                           0.62      1915
#    macro avg       0.31      0.50      0.38      1915
# weighted avg       0.39      0.62      0.48      1915
#
# Confusion Matrix:
#  [[   0  719]
#  [   0 1196]]
# Training Score:
#  63.82034208121164
# Mean Squared Error:
#  0.37545691906005224
# R2 score is:
#  -0.6011705685618727
# Accuracy Score:
#  62.45430809399478

# %% [markdown]
# # 4. Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gnb.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.39      0.09      0.15       719
#            1       0.63      0.91      0.74      1196
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#     accuracy                           0.60      1915
#    macro avg       0.25      0.25      0.22      1915
# weighted avg       0.54      0.60      0.52      1915
#
# Confusion Matrix:
#  [[  68  647    0    4]
#  [ 105 1086    3    2]
#  [   0    0    0    0]
#  [   0    0    0    0]]
# Training Score:
#  62.54080167123646
# Mean Squared Error:
#  0.4172323759791123
# R2 score is:
#  -0.7793258474004678
# Accuracy Score:
#  60.26109660574412

# %% [markdown]
# # 5. DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.63      0.48      0.55       719
#            1       0.73      0.83      0.78      1196
#
#     accuracy                           0.70      1915
#    macro avg       0.68      0.66      0.66      1915
# weighted avg       0.69      0.70      0.69      1915
#
# Confusion Matrix:
#  [[345 374]
#  [199 997]]
# Training Score:
#  74.00443922183054
# Mean Squared Error:
#  0.29921671018276763
# R2 score is:
#  -0.2760371846814369
# Accuracy Score:
#  70.07832898172323

# %% [markdown]
# # 6. RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.69      0.59      0.64       719
#            1       0.77      0.85      0.81      1196
#
#     accuracy                           0.75      1915
#    macro avg       0.73      0.72      0.72      1915
# weighted avg       0.74      0.75      0.74      1915
#
# Confusion Matrix:
#  [[ 421  298]
#  [ 185 1011]]
# Training Score:
#  100.0
# Mean Squared Error:
#  0.25221932114882506
# R2 score is:
#  -0.07561249598801756
# Accuracy Score:
#  74.7780678851175

# %% [markdown]
# # 7. AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier(base_estimator = None)
adb.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=adb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",adb.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.56      0.08      0.14       719
#            1       0.65      0.95      0.77      1196
#            3       0.00      0.00      0.00         0
#
#     accuracy                           0.62      1915
#    macro avg       0.40      0.34      0.30      1915
# weighted avg       0.61      0.62      0.53      1915
#
# Confusion Matrix:
#  [[  59  622   38]
#  [  47 1136   13]
#  [   0    0    0]]
# Training Score:
#  62.99778038908473
# Mean Squared Error:
#  0.5550913838120104
# R2 score is:
#  -1.3672382675678314
# Accuracy Score:
#  62.40208877284596

# %% [markdown]
# # 8. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred=gbc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gbc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.69      0.52      0.59       719
#            1       0.75      0.86      0.80      1196
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.73      1915
#    macro avg       0.48      0.46      0.46      1915
# weighted avg       0.73      0.73      0.72      1915
#
# Confusion Matrix:
#  [[ 374  345    0]
#  [ 170 1025    1]
#  [   0    0    0]]
# Training Score:
#  78.45671758715237
# Mean Squared Error:
#  0.2694516971279373
# R2 score is:
#  -0.14910154850893798
# Accuracy Score:
#  73.05483028720626

# %% [markdown]
# # 9. ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=100, random_state=0)
etc.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
y_pred=etc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",etc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
print("Accuracy Score:\n",accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.69      0.53      0.60       719
#            1       0.75      0.86      0.80      1196
#
#     accuracy                           0.73      1915
#    macro avg       0.72      0.69      0.70      1915
# weighted avg       0.73      0.73      0.73      1915
#
# Confusion Matrix:
#  [[ 383  336]
#  [ 173 1023]]
# Training Score:
#  100.0
# Mean Squared Error:
#  0.26579634464751956
# R2 score is:
#  -0.1335129616105608
# Accuracy Score:
#  73.42036553524804

# %% [markdown]
# # 10. Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
model = BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))
model.fit(x_train, y_train)
model.score(x_test,y_test)
conf =print(confusion_matrix(y_test, y_pred))
clf =print(classification_report(y_test, y_pred))
print("Training Score:\n",model.score(x_train,y_train)*100)
# Out:
# [[ 383  336]
#  [ 173 1023]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.53      0.60       719
#            1       0.75      0.86      0.80      1196
#
#     accuracy                           0.73      1915
#    macro avg       0.72      0.69      0.70      1915
# weighted avg       0.73      0.73      0.73      1915
#
# Training Score:
#  98.47238542890717

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#       Actual  Predicted
# 8188       0          0
# 9086       1          1
# 9          0          0
# 888        0          1
# 1082       1          1
# ...      ...        ...
# 491        1          1
# 6808       1          1
# 5385       0          0
# 6485       1          1
# 6604       1          0
#
# [1915 rows x 2 columns]

# %% [markdown]
# **Conclusion :**
#
# **So we get a good accuracy score of 98.47 % using the Bagging Classifier.**
